# %%
import random
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import spacy
from utils import translate_sentence, bleu, save_checkpoint, load_checkpoint
from torch.utils.tensorboard import SummaryWriter  # to print to tensorboard
from torchtext.datasets import Multi30k
from torchtext.data import Field, BucketIterator

"""
To install spacy languages do:
python -m spacy download en
python -m spacy download de
"""
spacy_ger = spacy.load("de")
spacy_eng = spacy.load("en")


def tokenize_ger(text):
    return [tok.text for tok in spacy_ger.tokenizer(text)]


def tokenize_eng(text):
    return [tok.text for tok in spacy_eng.tokenizer(text)]


german = Field(tokenize=tokenize_ger, lower=True, init_token="<sos>", eos_token="<eos>")

english = Field(
    tokenize=tokenize_eng, lower=True, init_token="<sos>", eos_token="<eos>"
)

train_data, valid_data, test_data = Multi30k.splits(
    exts=(".de", ".en"), fields=(german, english)
)

german.build_vocab(train_data, max_size=10000, min_freq=2)
english.build_vocab(train_data, max_size=10000, min_freq=2)


class Encoder(nn.Module):
    def __init__(self, input_size, embedding_size, hidden_size, num_layers, p):
        super(Encoder, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers

        self.embedding = nn.Embedding(input_size, embedding_size)
        self.rnn = nn.LSTM(embedding_size, hidden_size, num_layers, bidirectional=True)

        self.fc_hidden = nn.Linear(hidden_size * 2, hidden_size)
        self.fc_cell = nn.Linear(hidden_size * 2, hidden_size)
        self.dropout = nn.Dropout(p)

    def forward(self, x):
        # x: (seq_length, N) where N is batch size

        embedding = self.dropout(self.embedding(x))
        # embedding shape: (seq_length, N, embedding_size)

        encoder_states, (hidden, cell) = self.rnn(embedding)
        # outputs shape: (seq_length, N, hidden_size)

        # Use forward, backward cells and hidden through a linear layer
        # so that it can be input to the decoder which is not bidirectional
        # Also using index slicing ([idx:idx+1]) to keep the dimension
        hidden = self.fc_hidden(torch.cat((hidden[0:1], hidden[1:2]), dim=2))
        cell = self.fc_cell(torch.cat((cell[0:1], cell[1:2]), dim=2))

        return encoder_states, hidden, cell


class Decoder(nn.Module):
    def __init__(
        self, input_size, embedding_size, hidden_size, output_size, num_layers, p
    ):
        super(Decoder, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers

        self.embedding = nn.Embedding(input_size, embedding_size)
        self.rnn = nn.LSTM(hidden_size * 2 + embedding_size, hidden_size, num_layers)

        self.energy = nn.Linear(hidden_size * 3, 1)
        self.fc = nn.Linear(hidden_size, output_size)
        self.dropout = nn.Dropout(p)
        self.softmax = nn.Softmax(dim=0)
        self.relu = nn.ReLU()

    def forward(self, x, encoder_states, hidden, cell):
        x = x.unsqueeze(0)
        # x: (1, N) where N is the batch size

        embedding = self.dropout(self.embedding(x))
        # embedding shape: (1, N, embedding_size)

        sequence_length = encoder_states.shape[0]
        h_reshaped = hidden.repeat(sequence_length, 1, 1)
        # h_reshaped: (seq_length, N, hidden_size*2)

        energy = self.relu(self.energy(torch.cat((h_reshaped, encoder_states), dim=2)))
        # energy: (seq_length, N, 1)

        attention = self.softmax(energy)
        # attention: (seq_length, N, 1)

        # attention: (seq_length, N, 1), snk
        # encoder_states: (seq_length, N, hidden_size*2), snl
        # we want context_vector: (1, N, hidden_size*2), i.e knl
        context_vector = torch.einsum("snk,snl->knl", attention, encoder_states)

        rnn_input = torch.cat((context_vector, embedding), dim=2)
        # rnn_input: (1, N, hidden_size*2 + embedding_size)

        outputs, (hidden, cell) = self.rnn(rnn_input, (hidden, cell))
        # outputs shape: (1, N, hidden_size)

        predictions = self.fc(outputs).squeeze(0)
        # predictions: (N, hidden_size)

        return predictions, hidden, cell


class Seq2Seq(nn.Module):
    def __init__(self, encoder, decoder):
        super(Seq2Seq, self).__init__()
        self.encoder = encoder
        self.decoder = decoder

    def forward(self, source, target, teacher_force_ratio=0.5):
        batch_size = source.shape[1]
        target_len = target.shape[0]
        target_vocab_size = len(english.vocab)

        outputs = torch.zeros(target_len, batch_size, target_vocab_size).to(device)
        encoder_states, hidden, cell = self.encoder(source)

        # First input will be <SOS> token
        x = target[0]

        for t in range(1, target_len):
            # At every time step use encoder_states and update hidden, cell
            output, hidden, cell = self.decoder(x, encoder_states, hidden, cell)

            # Store prediction for current time step
            outputs[t] = output

            # Get the best word the Decoder predicted (index in the vocabulary)
            best_guess = output.argmax(1)

            # With probability of teacher_force_ratio we take the actual next word
            # otherwise we take the word that the Decoder predicted it to be.
            # Teacher Forcing is used so that the model gets used to seeing
            # similar inputs at training and testing time, if teacher forcing is 1
            # then inputs at test time might be completely different than what the
            # network is used to. This was a long comment.
            x = target[t] if random.random() < teacher_force_ratio else best_guess

        return outputs


### We're ready to define everything we need for training our Seq2Seq model ###
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
load_model = False
save_model = True

# Training hyperparameters
num_epochs = 100
learning_rate = 3e-4
batch_size = 32

# Model hyperparameters
input_size_encoder = len(german.vocab)
input_size_decoder = len(english.vocab)
output_size = len(english.vocab)
encoder_embedding_size = 300
decoder_embedding_size = 300
hidden_size = 1024
num_layers = 1
enc_dropout = 0.0
dec_dropout = 0.0

# Tensorboard to get nice loss plot
writer = SummaryWriter(f"runs/loss_plot")
step = 0

train_iterator, valid_iterator, test_iterator = BucketIterator.splits(
    (train_data, valid_data, test_data),
    batch_size=batch_size,
    sort_within_batch=True,
    sort_key=lambda x: len(x.src),
    device=device,
)

encoder_net = Encoder(
    input_size_encoder, encoder_embedding_size, hidden_size, num_layers, enc_dropout
).to(device)

decoder_net = Decoder(
    input_size_decoder,
    decoder_embedding_size,
    hidden_size,
    output_size,
    num_layers,
    dec_dropout,
).to(device)

model = Seq2Seq(encoder_net, decoder_net).to(device)
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

pad_idx = english.vocab.stoi["<pad>"]
criterion = nn.CrossEntropyLoss(ignore_index=pad_idx)

if load_model:
    load_checkpoint(torch.load("my_checkpoint.pth.tar"), model, optimizer)

sentence = (
    "ein boot mit mehreren männern darauf wird von einem großen"
    "pferdegespann ans ufer gezogen."
)

for epoch in range(num_epochs):
    print(f"[Epoch {epoch} / {num_epochs}]")

    if save_model:
        checkpoint = {
            "state_dict": model.state_dict(),
            "optimizer": optimizer.state_dict(),
        }
        save_checkpoint(checkpoint)

    model.eval()

    translated_sentence = translate_sentence(
        model, sentence, german, english, device, max_length=50
    )

    print(f"Translated example sentence: \n {translated_sentence}")

    model.train()

    for batch_idx, batch in enumerate(train_iterator):
        # Get input and targets and get to cuda
        inp_data = batch.src.to(device)
        target = batch.trg.to(device)

        # Forward prop
        output = model(inp_data, target)

        # Output is of shape (trg_len, batch_size, output_dim) but Cross Entropy Loss
        # doesn't take input in that form. For example if we have MNIST we want to have
        # output to be: (N, 10) and targets just (N). Here we can view it in a similar
        # way that we have output_words * batch_size that we want to send in into
        # our cost function, so we need to do some reshapin. While we're at it
        # Let's also remove the start token while we're at it
        output = output[1:].reshape(-1, output.shape[2])
        target = target[1:].reshape(-1)

        optimizer.zero_grad()
        loss = criterion(output, target)

        # Back prop
        loss.backward()

        # Clip to avoid exploding gradient issues, makes sure grads are
        # within a healthy range
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1)

        # Gradient descent step
        optimizer.step()

        # Plot to tensorboard
        writer.add_scalar("Training loss", loss, global_step=step)
        step += 1

# running on entire test data takes a while
score = bleu(test_data[1:100], model, german, english, device)
print(f"Bleu score {score * 100:.2f}")

# %%
import pandas as pd

# %%
data = pd.read_csv("cornell/preprocessed_movie_lines.txt",error_bad_lines=False)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
# !ls cornell
# Out:
# chameleons.pdf		       movie_titles_metadata.txt
# movie_characters_metadata.txt  preprocessed_movie_lines.txt
# movie_conversations.txt        raw_script_urls.txt
# movie_lines.txt		       README.txt

# %%
len(data)
# Out:
# 197615

# %%
data.head()
# Out:
#   they do not !
# 0  they do to !
# 1   i hope so .
# 2    she okay ?
# 3   let 's go .
# 4           wow

# %%
from data_reader import DataReader, PAD_TOKEN, EOS_TOKEN, GO_TOKEN
import random
class MovieDialogReader():
    """
    DataReader used to read and tokenize data from the Cornell open movie
    dialog dataset.
    """

    UNKNOWN_TOKEN = "UNK"

    DROPOUT_TOKENS = {"a", "an", "the", "'ll", "'s", "'m", "'ve", "to"}  # Add "to"

    REPLACEMENTS = {"there": "their", "their": "there", "then": "than",
                    "than": "then"}
    # Add: "be":"to"

    def __init__(self, train_path=None, token_to_id=None,
                 dropout_prob=0.37,replacement_prob=0.37, dataset_copies=2):
#         super(MovieDialogReader, self).__init__(
#             config, train_path=train_path, token_to_id=token_to_id,
#             special_tokens=[
#                 PAD_TOKEN, GO_TOKEN, EOS_TOKEN,
#                 MovieDialogReader.UNKNOWN_TOKEN],
#             dataset_copies=dataset_copies)

        self.dropout_prob = dropout_prob
        self.replacement_prob = replacement_prob

#         self.UNKNOWN_ID = self.token_to_id[MovieDialogReader.UNKNOWN_TOKEN]

    def read_samples_by_string(self, path):
        for tokens in self.read_tokens(path):
            source = []
            target = []

            for token in tokens:
                target.append(token)

                # Randomly dropout some words from the input.
                dropout_token = (token in MovieDialogReader.DROPOUT_TOKENS and
                                random.random() < self.dropout_prob)
                replace_token = (token in MovieDialogReader.REPLACEMENTS and
                                random.random() < self.replacement_prob)

                if replace_token:
                    source.append(MovieDialogReader.REPLACEMENTS[token])
                elif not dropout_token:
                    source.append(token)

            yield source, target

    def unknown_token(self):
        return MovieDialogReader.UNKNOWN_TOKEN

    def read_tokens(self, path):
        for line in range(len(path)):
            linep = path.iloc[line,:][0]
            yield linep.lower().strip().split()

# %%
m =  MovieDialogReader()

# %%
pairs = m.read_samples_by_string(data)

# %%
pairs
# Out:
# <generator object MovieDialogReader.read_samples_by_string at 0x7fb695444258>

# %%
for i in pairs:
    print(i)
# Out:
# (['they', 'do', 'to', '!'], ['they', 'do', 'to', '!'])
# (['i', 'hope', 'so', '.'], ['i', 'hope', 'so', '.'])
# (['she', 'okay', '?'], ['she', 'okay', '?'])
# (['let', "'s", 'go', '.'], ['let', "'s", 'go', '.'])
# (['wow'], ['wow'])
# (['okay', '--', 'you', "'re", 'gon', 'na', 'need', 'to', 'learn', 'how', 'to', 'lie', '.'], ['okay', '--', 'you', "'re", 'gon', 'na', 'need', 'to', 'learn', 'how', 'to', 'lie', '.'])
# (['no'], ['no'])
# (['i', "'m", 'kidding', '.', 'you', 'know', 'how', 'sometimes', 'you', 'just', 'become', 'this', '``', 'persona', "''", '?', 'and', 'you', 'do', "n't", 'know', 'how', 'quit', '?'], ['i', "'m", 'kidding', '.', 'you', 'know', 'how', 'sometimes', 'you', 'just', 'become', 'this', '``', 'persona', "''", '?', 'and', 'you', 'do', "n't", 'know', 'how', 'to', 'quit', '?'])
# (['like', 'my', 'fear', 'of', 'wearing', 'pastels', '?'], ['like', 'my', 'fear', 'of', 'wearing', 'pastels', '?'])
# (['the', '``', 'real', 'you', "''", '.'], ['the', '``', 'real', 'you', "''", '.'])
# (['what', 'good', 'stuff', '?'], ['what', 'good', 'stuff', '?'])
# (['i', 'figured', 'you', "'d", 'get', 'to', 'the', 'good', 'stuff', 'eventually', '.'], ['i', 'figured', 'you', "'d", 'get', 'to', 'the', 'good', 'stuff', 'eventually', '.'])
# (['thank', 'god', '!', 'if', 'i', 'had', 'hear', 'one', 'more', 'story', 'about', 'your', 'coiffure', '...'], ['thank', 'god', '!', 'if', 'i', 'had', 'to', 'hear', 'one', 'more', 'story', 'about', 'your', 'coiffure', '...'])
# (['what', 'crap', '?'], ['what', 'crap', '?'])
# (['do', 'you', 'listen', 'to', 'this', 'crap', '?'], ['do', 'you', 'listen', 'to', 'this', 'crap', '?'])
# (['no', '...'], ['no', '...'])
# (['you', 'always', 'been', 'this', 'selfish', '?'], ['you', 'always', 'been', 'this', 'selfish', '?'])
# (['but'], ['but'])
# (['then', 'that', "'s", 'all', 'you', 'had', 'to', 'say', '.'], ['then', 'that', "'s", 'all', 'you', 'had', 'to', 'say', '.'])
# (['i', 'was', '?'], ['i', 'was', '?'])
# (['tons'], ['tons'])
# (['have', 'fun', 'tonight', '?'], ['have', 'fun', 'tonight', '?'])
# (['i', 'believe', 'we', 'share', 'art', 'instructor'], ['i', 'believe', 'we', 'share', 'an', 'art', 'instructor'])
# (['you', 'know', 'chastity', '?'], ['you', 'know', 'chastity', '?'])
# (['hi', '.'], ['hi', '.'])
# (['who', 'knows', '?', 'all', 'i', 'ever', 'heard', 'her', 'say', 'is', 'that', 'she', "'d", 'dip', 'before', 'dating', 'a', 'guy', 'that', 'smokes', '.'], ['who', 'knows', '?', 'all', 'i', "'ve", 'ever', 'heard', 'her', 'say', 'is', 'that', 'she', "'d", 'dip', 'before', 'dating', 'a', 'guy', 'that', 'smokes', '.'])
# (['so', 'that', "'s", 'the', 'kind', 'of', 'guy', 'she', 'likes', '?', 'pretty', 'ones', '?'], ['so', 'that', "'s", 'the', 'kind', 'of', 'guy', 'she', 'likes', '?', 'pretty', 'ones', '?'])
# (['she', "'s", 'not', 'a', '...'], ['she', "'s", 'not', 'a', '...'])
# (['i', "'m", 'workin', "'", 'on', 'it', '.', 'but', 'she', 'does', "n't", 'seem', 'be', 'goin', "'", 'for', 'him', '.'], ['i', "'m", 'workin', "'", 'on', 'it', '.', 'but', 'she', 'does', "n't", 'seem', 'to', 'be', 'goin', "'", 'for', 'him', '.'])
# (['sure', 'have', '.'], ['sure', 'have', '.'])
# (['how', 'do', 'you', 'get', 'your', 'hair', 'to', 'look', 'like', 'that', '?'], ['how', 'do', 'you', 'get', 'your', 'hair', 'to', 'look', 'like', 'that', '?'])
# (['you', "'re", 'sweet', '.'], ['you', "'re", 'sweet', '.'])
# (['you', 'have', 'my', 'word', '.', 'as', 'gentleman'], ['you', 'have', 'my', 'word', '.', 'as', 'a', 'gentleman'])
# (['i', 'counted', 'on', 'you', 'to', 'help', 'my', 'cause', '.', 'you', 'and', 'that', 'thug', 'are', 'obviously', 'failing', '.', 'are', "n't", 'we', 'ever', 'going', 'on', 'our', 'date', '?'], ['i', 'counted', 'on', 'you', 'to', 'help', 'my', 'cause', '.', 'you', 'and', 'that', 'thug', 'are', 'obviously', 'failing', '.', 'are', "n't", 'we', 'ever', 'going', 'on', 'our', 'date', '?'])
# (['you', 'got', 'something', 'on', 'your', 'mind', '?'], ['you', 'got', 'something', 'on', 'your', 'mind', '?'])
# (['where', '?'], ['where', '?'])
# (['their', '.'], ['there', '.'])
# (['how', 'is', 'our', 'little', 'find', 'wench', 'date', 'plan', 'progressing', '?'], ['how', 'is', 'our', 'little', 'find', 'the', 'wench', 'a', 'date', 'plan', 'progressing', '?'])
# (['forget', 'french', '.'], ['forget', 'french', '.'])
# (['that', "'s", 'because', 'it', "'s", 'such', 'nice', 'one', '.'], ['that', "'s", 'because', 'it', "'s", 'such', 'a', 'nice', 'one', '.'])
# (['i', 'do', "n't", 'want', 'know', 'how', 'to', 'say', 'that', 'though', '.', 'i', 'want', 'know', 'useful', 'things', '.', 'like', 'where', 'the', 'good', 'stores', 'are', '.', 'how', 'much', 'does', 'champagne', 'cost', '?', 'stuff', 'like', 'chat', '.', 'i', 'have', 'never', 'in', 'my', 'life', 'had', 'point', 'out', 'my', 'head', 'someone', '.'], ['i', 'do', "n't", 'want', 'to', 'know', 'how', 'to', 'say', 'that', 'though', '.', 'i', 'want', 'to', 'know', 'useful', 'things', '.', 'like', 'where', 'the', 'good', 'stores', 'are', '.', 'how', 'much', 'does', 'champagne', 'cost', '?', 'stuff', 'like', 'chat', '.', 'i', 'have', 'never', 'in', 'my', 'life', 'had', 'to', 'point', 'out', 'my', 'head', 'to', 'someone', '.'])
# (['right', '.', 'see', '?', 'you', "'re", 'ready', 'for', 'quiz', '.'], ['right', '.', 'see', '?', 'you', "'re", 'ready', 'for', 'the', 'quiz', '.'])
# (["c'esc", 'ma', 'tete', '.', 'this', 'is', 'my', 'head'], ["c'esc", 'ma', 'tete', '.', 'this', 'is', 'my', 'head'])
# (['let', 'me', 'see', 'what', 'i', 'can', 'do', '.'], ['let', 'me', 'see', 'what', 'i', 'can', 'do', '.'])
# (['that', "'s", 'a', 'shame', '.'], ['that', "'s", 'a', 'shame', '.'])
# (['why', '?'], ['why', '?'])
# (['seems', 'like', 'she', 'could', 'get', 'date', 'easy', 'enough', '...'], ['seems', 'like', 'she', 'could', 'get', 'a', 'date', 'easy', 'enough', '...'])
# (['cameron', '.'], ['cameron', '.'])
# (['forget', 'it', '.'], ['forget', 'it', '.'])
# (['you', "'re", 'asking', 'me', 'out', '.', 'that', "'s", 'so', 'cute', '.', 'what', "'s", 'your', 'name', 'again', '?'], ['you', "'re", 'asking', 'me', 'out', '.', 'that', "'s", 'so', 'cute', '.', 'what', "'s", 'your', 'name', 'again', '?'])
# (['okay', '...', 'than', 'how', "'bout", 'we', 'try', 'out', 'some', 'french', 'cuisine', '.', 'saturday', '?', 'night', '?'], ['okay', '...', 'then', 'how', "'bout", 'we', 'try', 'out', 'some', 'french', 'cuisine', '.', 'saturday', '?', 'night', '?'])
# (['not', 'the', 'hacking', 'and', 'gagging', 'and', 'spitting', 'part', '.', 'please', '.'], ['not', 'the', 'hacking', 'and', 'gagging', 'and', 'spitting', 'part', '.', 'please', '.'])
# (['can', 'we', 'make', 'this', 'quick', '?', 'roxanne', 'korrine', 'and', 'andrew', 'barrett', 'are', 'having', 'incredibly', 'horrendous', 'public', 'break-', 'up', 'on', 'the', 'quad', '.', 'again', '.'], ['can', 'we', 'make', 'this', 'quick', '?', 'roxanne', 'korrine', 'and', 'andrew', 'barrett', 'are', 'having', 'an', 'incredibly', 'horrendous', 'public', 'break-', 'up', 'on', 'the', 'quad', '.', 'again', '.'])
# (['i', 'did', '.'], ['i', 'did', '.'])
# (['you', 'think', 'you', "'", 're', 'the', 'only', 'sophomore', 'at', 'the', 'prom', '?'], ['you', 'think', 'you', "'", 're', 'the', 'only', 'sophomore', 'at', 'the', 'prom', '?'])
# (['i', 'do', "n't", 'have', 'to', 'be', 'home', "'til", 'two', '.'], ['i', 'do', "n't", 'have', 'to', 'be', 'home', "'til", 'two', '.'])
# (['i', 'have', 'to', 'be', 'home', 'in', 'twenty', 'minutes', '.'], ['i', 'have', 'to', 'be', 'home', 'in', 'twenty', 'minutes', '.'])
# (['all', 'i', 'know', 'is', '--', 'i', "'d", 'give', 'up', 'my', 'private', 'line', 'to', 'go', 'out', 'with', 'a', 'guy', 'like', 'joey', '.'], ['all', 'i', 'know', 'is', '--', 'i', "'d", 'give', 'up', 'my', 'private', 'line', 'to', 'go', 'out', 'with', 'a', 'guy', 'like', 'joey', '.'])
# (['combination', '.', 'i', 'do', "n't", 'know', '--', 'i', 'thought', 'he', "'d", 'be', 'different', '.', 'more', 'of', 'a', 'gentleman', '...'], ['combination', '.', 'i', 'do', "n't", 'know', '--', 'i', 'thought', 'he', "'d", 'be', 'different', '.', 'more', 'of', 'a', 'gentleman', '...'])
# (['is', 'he', 'oily', 'or', 'dry', '?'], ['is', 'he', 'oily', 'or', 'dry', '?'])
# (['great'], ['great'])
# (['joey', '.'], ['joey', '.'])
# (['who', '?'], ['who', '?'])
# (['where', 'did', 'he', 'go', '?', 'he', 'was', 'just', 'here', '.'], ['where', 'did', 'he', 'go', '?', 'he', 'was', 'just', 'here', '.'])
# (['you', 'might', 'wan', 'na', 'think', 'about', 'it'], ['you', 'might', 'wan', 'na', 'think', 'about', 'it'])
# (['no', '.'], ['no', '.'])
# (['did', 'you', 'change', 'your', 'hair', '?'], ['did', 'you', 'change', 'your', 'hair', '?'])
# (['you', 'know', 'deal', '.', 'i', 'can', "'", 't', 'go', 'if', 'kat', 'does', "n't", 'go', '--'], ['you', 'know', 'the', 'deal', '.', 'i', 'can', "'", 't', 'go', 'if', 'kat', 'does', "n't", 'go', '--'])
# (['you', "'re", 'concentrating', 'awfully', 'hard', 'considering', 'it', 'gym', 'class', '.'], ['you', "'re", 'concentrating', 'awfully', 'hard', 'considering', 'it', "'s", 'gym', 'class', '.'])
# (['my', 'agent', 'says', 'i', "'ve", 'got', 'a', 'good', 'shot', 'at', 'being', 'the', 'prada', 'guy', 'next', 'year', '.'], ['my', 'agent', 'says', 'i', "'ve", 'got', 'a', 'good', 'shot', 'at', 'being', 'the', 'prada', 'guy', 'next', 'year', '.'])
# (['neat', '...'], ['neat', '...'])
# (['queen', 'harry', '?'], ['queen', 'harry', '?'])
# (['hopefully', '.'], ['hopefully', '.'])
# (['expensive', '?'], ['expensive', '?'])
# (['it', "'s", 'more'], ['it', "'s", 'more'])
# (['perm', '?'], ['perm', '?'])
# (['patrick', '--', 'is', 'that-', 'a', '.'], ['patrick', '--', 'is', 'that-', 'a', '.'])
# (['it', 'just', 'you', '.'], ['it', "'s", 'just', 'you', '.'])
# (['is', 'that', 'woman', 'a', 'complete', 'fruit-loop', 'or', 'is', 'it', 'just', 'me', '?'], ['is', 'that', 'woman', 'a', 'complete', 'fruit-loop', 'or', 'is', 'it', 'just', 'me', '?'])
# (['no', '!', 'i', 'just', 'wanted'], ['no', '!', 'i', 'just', 'wanted'])
# (['what', '?', 'completely', 'damage', 'me', '?', 'to', 'send', 'me', 'to', 'therapy', 'forever', '?', 'what', '?'], ['what', '?', 'to', 'completely', 'damage', 'me', '?', 'to', 'send', 'me', 'to', 'therapy', 'forever', '?', 'what', '?'])
# (['i', 'just', 'wanted', '--'], ['i', 'just', 'wanted', '--'])
# (['you', 'set', 'me', 'up', '.'], ['you', 'set', 'me', 'up', '.'])
# (['let', 'go', '!'], ['let', 'go', '!'])
# (['so', 'did', 'you'], ['so', 'did', 'you'])
# (['i', 'guess', 'i', 'thought', 'i', 'was', 'protecting', 'you', '.'], ['i', 'guess', 'i', 'thought', 'i', 'was', 'protecting', 'you', '.'])
# (['i', 'not', 'stupid', 'enough', 'repeat', 'your', 'mistakes', '.'], ['i', "'m", 'not', 'stupid', 'enough', 'to', 'repeat', 'your', 'mistakes', '.'])
# (['that', "'s", 'not'], ['that', "'s", 'not'])
# (['i', 'wanted', 'let', 'you', 'make', 'up', 'your', 'own', 'mind', 'about', 'him', '.'], ['i', 'wanted', 'to', 'let', 'you', 'make', 'up', 'your', 'own', 'mind', 'about', 'him', '.'])
# (['why', 'did', "n't", 'you', 'tell', 'me', '?'], ['why', 'did', "n't", 'you', 'tell', 'me', '?'])
# (['but'], ['but'])
# (['you', 'did', 'what', '?'], ['you', 'did', 'what', '?'])
# (['he', 'said', 'everyone', 'was', 'doing', 'it', '.', 'so', 'i', 'did', 'it', '.'], ['he', 'said', 'everyone', 'was', 'doing', 'it', '.', 'so', 'i', 'did', 'it', '.'])
# (['as', 'in', '...'], ['as', 'in', '...'])
# (['but', 'you', 'hate', 'joey'], ['but', 'you', 'hate', 'joey'])
# (['why', '?'], ['why', '?'])
# (['in', '9th', '.', 'for', 'a', 'month'], ['in', '9th', '.', 'for', 'a', 'month'])
# (['what', '?'], ['what', '?'])
# (['like', 'you', 'care', '.'], ['like', 'you', 'care', '.'])
# (['you', "'re", 'welcome', '.'], ['you', "'re", 'welcome', '.'])
# (['i', 'really', 'do', "n't", 'think', 'i', 'need', 'any', 'social', 'advice', 'from', 'you', 'right', 'now', '.'], ['i', 'really', 'do', "n't", 'think', 'i', 'need', 'any', 'social', 'advice', 'from', 'you', 'right', 'now', '.'])
# (['can', 'we', 'go', 'now', '?'], ['can', 'we', 'go', 'now', '?'])
# (['you', 'are', 'so', 'completely', 'unbalanced', '.'], ['you', 'are', 'so', 'completely', 'unbalanced', '.'])
# (['it', "'s", 'shakespeare', '.', 'maybe', 'you', "'ve", 'heard', 'of', 'him', '?'], ['it', "'s", 'shakespeare', '.', 'maybe', 'you', "'ve", 'heard', 'of', 'him', '?'])
# (['like', 'i', 'supposed', 'know', 'what', 'that', 'even', 'means', '.'], ['like', 'i', "'m", 'supposed', 'to', 'know', 'what', 'that', 'even', 'means', '.'])
# (['at', 'least', 'i', "'m", 'not', 'a', 'clouted', 'fen-', 'sucked', 'hedge-pig', '.'], ['at', 'least', 'i', "'m", 'not', 'a', 'clouted', 'fen-', 'sucked', 'hedge-pig', '.'])
# (['ca', "n't", 'you', 'forget', 'for', 'just', 'one', 'night', 'that', 'you', "'re", 'completely', 'wretched', '?'], ['ca', "n't", 'you', 'forget', 'for', 'just', 'one', 'night', 'that', 'you', "'re", 'completely', 'wretched', '?'])
# (['what', "'s", 'normal', '?'], ['what', "'s", 'normal', '?'])
# (['i', 'think', 'you', "'re", 'a', 'freak', '.', 'i', 'think', 'you', 'do', 'this', 'to', 'torture', 'me', '.', 'and', 'i', 'think', 'you', 'suck', '.'], ['i', 'think', 'you', "'re", 'a', 'freak', '.', 'i', 'think', 'you', 'do', 'this', 'to', 'torture', 'me', '.', 'and', 'i', 'think', 'you', 'suck', '.'])
# (['what', 'do', 'you', 'think', '?'], ['what', 'do', 'you', 'think', '?'])
# (['it', 'means', 'that', 'gigglepuss', 'is', 'playing', 'at', 'club', 'skunk', 'and', 'we', "'re", 'going', '.'], ['it', 'means', 'that', 'gigglepuss', 'is', 'playing', 'at', 'club', 'skunk', 'and', 'we', "'re", 'going', '.'])
# (['can', 'you', 'at', 'least', 'start', 'wearing', 'a', 'bra', '?'], ['can', 'you', 'at', 'least', 'start', 'wearing', 'a', 'bra', '?'])
# (['i', 'have', 'potential', 'to', 'smack', 'the', 'crap', 'out', 'of', 'you', 'if', 'you', 'do', "n't", 'get', 'out', 'of', 'my', 'way', '.'], ['i', 'have', 'the', 'potential', 'to', 'smack', 'the', 'crap', 'out', 'of', 'you', 'if', 'you', 'do', "n't", 'get', 'out', 'of', 'my', 'way', '.'])
# (['where', "'ve", 'you', 'been', '?'], ['where', "'ve", 'you', 'been', '?'])
# (['i', "'m", 'missing', 'something', '.'], ['i', "'m", 'missing', 'something', '.'])
# (['fine', '.', 'i', 'see', 'that', 'i', "'m", 'a', 'prisoner', 'in', 'my', 'own', 'house', '.', 'i', 'not', 'a', 'daughter', '.', 'i', "'m", 'possession', '!'], ['fine', '.', 'i', 'see', 'that', 'i', "'m", 'a', 'prisoner', 'in', 'my', 'own', 'house', '.', 'i', "'m", 'not', 'a', 'daughter', '.', 'i', "'m", 'a', 'possession', '!'])
# (['you', "'re", 'not', 'going', 'unless', 'your', 'sister', 'goes', '.', 'end', 'of', 'story', '.'], ['you', "'re", 'not', 'going', 'unless', 'your', 'sister', 'goes', '.', 'end', 'of', 'story', '.'])
# (['he', "'s", 'not', 'a', '``', 'hot', 'rod', "''", '.', 'whatever', 'that', 'is', '.'], ['he', "'s", 'not', 'a', '``', 'hot', 'rod', "''", '.', 'whatever', 'that', 'is', '.'])
# (['prom', '?', 'kat', 'has', 'a', 'date', '?'], ['the', 'prom', '?', 'kat', 'has', 'a', 'date', '?'])
# (['because', 'she', 'scare', 'them', 'away', '.'], ['because', 'she', "'ll", 'scare', 'them', 'away', '.'])
# (['why', '?'], ['why', '?'])
# (['promise', 'me', 'you', 'wo', "n't", 'talk', 'to', 'any', 'boys', 'unless', 'your', 'sister', 'is', 'present', '.'], ['promise', 'me', 'you', 'wo', "n't", 'talk', 'to', 'any', 'boys', 'unless', 'your', 'sister', 'is', 'present', '.'])
# (['just', 'for', 'minute'], ['just', 'for', 'a', 'minute'])
# (['wear', 'the', 'belly', 'before', 'you', 'go', '.'], ['wear', 'the', 'belly', 'before', 'you', 'go', '.'])
# (['it', 'just', 'party', '.', 'daddy', '.'], ['it', "'s", 'just', 'a', 'party', '.', 'daddy', '.'])
# (['otherwise', 'known', 'as', 'an', 'orgy', '?'], ['otherwise', 'known', 'as', 'an', 'orgy', '?'])
# (['and', 'where', "'re", 'you', 'going', '?'], ['and', 'where', "'re", 'you', 'going', '?'])
# (['exactly', 'my', 'point'], ['exactly', 'my', 'point'])
# (['but', 'she', 'does', "n't", 'want', 'date', '.'], ['but', 'she', 'does', "n't", 'want', 'to', 'date', '.'])
# (['than', 'neither', 'will', 'you', '.', 'and', 'i', "'ll", 'get', 'sleep', 'at', 'night', '.'], ['then', 'neither', 'will', 'you', '.', 'and', 'i', "'ll", 'get', 'to', 'sleep', 'at', 'night', '.'])
# (['what', 'if', 'she', 'never', 'starts', 'dating', '?'], ['what', 'if', 'she', 'never', 'starts', 'dating', '?'])
# (['no', '!', 'you', "'re", 'not', 'dating', 'until', 'your', 'sister', 'starts', 'dating', '.', 'end', 'of', 'discussion', '.'], ['no', '!', 'you', "'re", 'not', 'dating', 'until', 'your', 'sister', 'starts', 'dating', '.', 'end', 'of', 'discussion', '.'])
# (['just', 'sent', "'em", 'through', '.'], ['just', 'sent', "'em", 'through', '.'])
# (['never'], ['never'])
# (['fan', 'of', 'fan', '.', 'you', 'see', 'a', 'couple', 'of', 'minors', 'come', 'in', '?'], ['fan', 'of', 'a', 'fan', '.', 'you', 'see', 'a', 'couple', 'of', 'minors', 'come', 'in', '?'])
# (['did', "n't", 'have', 'you', 'pegged', 'for', 'a', 'gigglepuss', 'fan', '.', 'are', "n't", 'they', 'a', 'little', 'too', 'pre-teen', 'belly-button', 'ring', 'for', 'you', '?'], ['did', "n't", 'have', 'you', 'pegged', 'for', 'a', 'gigglepuss', 'fan', '.', 'are', "n't", 'they', 'a', 'little', 'too', 'pre-teen', 'belly-button', 'ring', 'for', 'you', '?'])
# (['you', 'humiliated', 'woman', '!', 'sacrifice', 'yourself', 'on', 'altar', 'of', 'dignity', 'and', 'even', 'score', '.'], ['you', 'humiliated', 'the', 'woman', '!', 'sacrifice', 'yourself', 'on', 'the', 'altar', 'of', 'dignity', 'and', 'even', 'the', 'score', '.'])
# (['the', 'hell', 'is', 'that', '?', 'what', 'kind', 'of', "'guy", 'just', 'picks', 'up', 'a', 'girl', 'and', 'carries', 'her', 'away', 'while', 'you', "'re", 'talking', 'to', 'her', '?'], ['the', 'hell', 'is', 'that', '?', 'what', 'kind', 'of', "'guy", 'just', 'picks', 'up', 'a', 'girl', 'and', 'carries', 'her', 'away', 'while', 'you', "'re", 'talking', 'to', 'her', '?'])
# (['extremely', 'unfortunate', 'maneuver', '.'], ['extremely', 'unfortunate', 'maneuver', '.'])
# (['you', 'told', 'me', 'that', 'part', 'already', '.'], ['you', 'told', 'me', 'that', 'part', 'already', '.'])
# (['it', "'s", 'her', 'favorite', 'band', '.'], ['it', "'s", 'her', 'favorite', 'band', '.'])
# (['assail', 'your', 'ears', 'for', 'one', 'night', '.'], ['assail', 'your', 'ears', 'for', 'one', 'night', '.'])
# (['okay', '!', 'i', 'was', "n't", 'sure'], ['okay', '!', 'i', 'was', "n't", 'sure'])
# (['he', "'s", 'pretty', '!'], ['he', "'s", 'pretty', '!'])
# (['dead', 'at', 'forty-one', '.'], ['dead', 'at', 'forty-one', '.'])
# (['her', 'favorite', 'uncle'], ['her', 'favorite', 'uncle'])
# (['it', 'lung', 'cancer', 'issue'], ['it', "'s", 'a', 'lung', 'cancer', 'issue'])
# (['number', 'one', '.', 'she', 'hates', 'smokers'], ['number', 'one', '.', 'she', 'hates', 'smokers'])
# (['are', 'you', 'kidding', '?', 'he', 'piss', 'himself', 'with', 'joy', '.', 'he', "'s", 'ultimate', 'kiss', 'ass', '.'], ['are', 'you', 'kidding', '?', 'he', "'ll", 'piss', 'himself', 'with', 'joy', '.', 'he', "'s", 'the', 'ultimate', 'kiss', 'ass', '.'])
# (['will', 'bogey', 'get', 'bent', '?'], ['will', 'bogey', 'get', 'bent', '?'])
# (['this', 'is', 'it', '.', 'a', 'golden', 'opportunity', '.', 'patrick', 'can', 'ask', 'katarina', 'party', '.'], ['this', 'is', 'it', '.', 'a', 'golden', 'opportunity', '.', 'patrick', 'can', 'ask', 'katarina', 'to', 'the', 'party', '.'])
# (['you', 'got', 'him', 'involved', '?'], ['you', 'got', 'him', 'involved', '?'])
# (['hey', '--', 'i', "'ve", 'got', 'ta', 'have', 'a', 'few', 'clients', 'when', 'i', 'get', 'to', 'wall', 'street', '.'], ['hey', '--', 'i', "'ve", 'got', 'ta', 'have', 'a', 'few', 'clients', 'when', 'i', 'get', 'to', 'wall', 'street', '.'])
# (['i', 'thought', 'you', 'hated', 'those', 'people', '.'], ['i', 'thought', 'you', 'hated', 'those', 'people', '.'])
# (['that', 'what', 'i', 'just', 'said'], ['that', "'s", 'what', 'i', 'just', 'said'])
# (['did', 'she', 'actually', 'say', 'she', "'d", 'go', 'out', 'with', 'you', '?'], ['did', 'she', 'actually', 'say', 'she', "'d", 'go', 'out', 'with', 'you', '?'])
# (['forget', 'his', 'reputation', '.', 'do', 'you', 'think', 'we', 'got', 'plan', 'or', 'not', '?'], ['forget', 'his', 'reputation', '.', 'do', 'you', 'think', 'we', "'ve", 'got', 'a', 'plan', 'or', 'not', '?'])
# (['they', 'always', 'let', 'felons', 'sit', 'in', 'on', 'honors', 'biology', '?'], ['they', 'always', 'let', 'felons', 'sit', 'in', 'on', 'honors', 'biology', '?'])
# (['no', 'kidding', '.', 'he', "'s", 'criminal', '.', 'i', 'heard', 'he', 'lit', 'a', 'state', 'trooper', 'on', 'fire', '.', 'he', 'just', 'got', 'out', 'of', 'alcatraz', '...'], ['no', 'kidding', '.', 'he', "'s", 'a', 'criminal', '.', 'i', 'heard', 'he', 'lit', 'a', 'state', 'trooper', 'on', 'fire', '.', 'he', 'just', 'got', 'out', 'of', 'alcatraz', '...'])
# (['he', 'seems', 'like', 'he', 'thrives', 'on', 'danger'], ['he', 'seems', 'like', 'he', 'thrives', 'on', 'danger'])
# (['what', 'makes', 'you', 'think', 'he', "'ll", 'do', 'it', '?'], ['what', 'makes', 'you', 'think', 'he', "'ll", 'do', 'it', '?'])
# (['you', 'wan', 'na', 'go', 'out', 'with', 'him', '?'], ['you', 'wan', 'na', 'go', 'out', 'with', 'him', '?'])
# (['what', 'about', 'him', '?'], ['what', 'about', 'him', '?'])
# (['that', "'s", 'her', '?', 'bianca', "'s", 'sister', '?'], ['that', "'s", 'her', '?', 'bianca', "'s", 'sister', '?'])
# (['you', 'mean', 'i', "'d", 'get', 'a', 'chance', 'talk', 'her', '?'], ['you', 'mean', 'i', "'d", 'get', 'a', 'chance', 'to', 'talk', 'to', 'her', '?'])
# (['guess', 'who', 'just', 'signed', 'up', 'for', 'tutor', '?'], ['guess', 'who', 'just', 'signed', 'up', 'for', 'a', 'tutor', '?'])
# (['sure', 'do', '...', 'my', 'mom', 'from', 'canada'], ['sure', 'do', '...', 'my', 'mom', "'s", 'from', 'canada'])
# (['you', 'know', 'french', '?'], ['you', 'know', 'french', '?'])
# (['he', 'always', 'have', 'that', 'shit-eating', 'grin', '?'], ['he', 'always', 'have', 'that', 'shit-eating', 'grin', '?'])
# (['why', 'do', 'girls', 'like', 'that', 'always', 'like', 'guys', 'like', 'that', '?'], ['why', 'do', 'girls', 'like', 'that', 'always', 'like', 'guys', 'like', 'that', '?'])
# (['why', 'not', '?'], ['why', 'not', '?'])
# (['bianca', 'stratford', '.', 'sophomore', '.', 'do', "n't", 'even', 'think', 'about', 'it'], ['bianca', 'stratford', '.', 'sophomore', '.', 'do', "n't", 'even', 'think', 'about', 'it'])
# (['who', 'is', 'she', '?'], ['who', 'is', 'she', '?'])
# (['that', 'girl', '--', 'i', '--'], ['that', 'girl', '--', 'i', '--'])
# (['that', 'i', "'m", 'used', 'to', '.'], ['that', 'i', "'m", 'used', 'to', '.'])
# (['couple', 'thousand', '.', 'most', 'of', 'them', 'evil'], ['couple', 'thousand', '.', 'most', 'of', 'them', 'evil'])
# (['how', 'many', 'people', 'go', 'here', '?'], ['how', 'many', 'people', 'go', 'here', '?'])
# (['get', 'out', '!'], ['get', 'out', '!'])
# (['thirty-two', '.'], ['thirty-two', '.'])
# (['how', 'many', 'people', 'were', 'in', 'your', 'old', 'school', '?'], ['how', 'many', 'people', 'were', 'in', 'your', 'old', 'school', '?'])
# (['i', 'was', 'kidding', '.', 'people', 'actually', 'live', 'their', '?'], ['i', 'was', 'kidding', '.', 'people', 'actually', 'live', 'there', '?'])
# (['so', '--', 'which', 'dakota', 'you', 'from', '?'], ['so', '--', 'which', 'dakota', 'you', 'from', '?'])
# (["c'mon", '.', 'i', "'m", 'supposed', 'to', 'give', 'you', 'tour', '.'], ["c'mon", '.', 'i', "'m", 'supposed', 'to', 'give', 'you', 'the', 'tour', '.'])
# (['so', 'they', 'tell', 'me', '...'], ['so', 'they', 'tell', 'me', '...'])
# (['you', 'new', 'guy', '?'], ['you', 'the', 'new', 'guy', '?'])
# (['you', 'get', 'girl', '.'], ['you', 'get', 'the', 'girl', '.'])
# (['what', "'s", 'worst', '?'], ['what', "'s", 'the', 'worst', '?'])
# (['where', '?'], ['where', '?'])
# (['she', 'kissed', 'me', '.'], ['she', 'kissed', 'me', '.'])
# (['you', 'makin', "'", 'any', 'headway', '?'], ['you', 'makin', "'", 'any', 'headway', '?'])
# (['she', 'just', 'needs', 'time', 'to', 'cool', 'off', 'i', "'ll", 'give', 'it', 'a', 'day', '.'], ['she', 'just', 'needs', 'time', 'to', 'cool', 'off', 'i', "'ll", 'give', 'it', 'a', 'day', '.'])
# (['she', 'hates', 'you', 'with', 'the', 'fire', 'of', 'a', 'thousand', 'suns', '.', 'that', "'s", 'direct', 'quote'], ['she', 'hates', 'you', 'with', 'the', 'fire', 'of', 'a', 'thousand', 'suns', '.', 'that', "'s", 'a', 'direct', 'quote'])
# (['i', 'don', "'", 't', 'know', '.', 'i', 'decided', 'not', 'to', 'nail', 'her', 'when', 'she', 'was', 'too', 'drunk', 'to', 'remember', 'it', '.'], ['i', 'don', "'", 't', 'know', '.', 'i', 'decided', 'not', 'to', 'nail', 'her', 'when', 'she', 'was', 'too', 'drunk', 'to', 'remember', 'it', '.'])
# (['what', "'d", 'you', 'do', 'to', 'her', '?'], ['what', "'d", 'you', 'do', 'to', 'her', '?'])
# (['sure'], ['sure'])
# (['cameron', '--', 'do', 'you', 'like', 'the', 'girl', '?'], ['cameron', '--', 'do', 'you', 'like', 'the', 'girl', '?'])
# (['what', "'re", 'you', 'talking', 'about', '?'], ['what', "'re", 'you', 'talking', 'about', '?'])
# (['it', 'off', '.', 'the', 'whole', 'thing', '.'], ['it', "'s", 'off', '.', 'the', 'whole', 'thing', '.'])
# (['gigglepuss', 'is', 'playing', 'there', 'tomorrow', 'night', '.'], ['gigglepuss', 'is', 'playing', 'there', 'tomorrow', 'night', '.'])
# (['so', 'what', 'does', 'that', 'give', 'me', '?', 'i', "'m", 'supposed', 'to', 'buy', 'her', 'some', 'noodles', 'and', 'a', 'book', 'and', 'sit', 'around', 'listening', 'to', 'chicks', 'who', 'ca', "n't", 'play', 'their', 'instruments', '?'], ['so', 'what', 'does', 'that', 'give', 'me', '?', 'i', "'m", 'supposed', 'to', 'buy', 'her', 'some', 'noodles', 'and', 'a', 'book', 'and', 'sit', 'around', 'listening', 'to', 'chicks', 'who', 'ca', "n't", 'play', 'their', 'instruments', '?'])
# (['i', "'ve", 'retrieved', 'certain', 'pieces', 'of', 'information', 'on', 'miss', 'katarina', 'stratford', 'i', 'think', 'you', "'ll", 'find', 'helpful', '.'], ['i', "'ve", 'retrieved', 'certain', 'pieces', 'of', 'information', 'on', 'miss', 'katarina', 'stratford', 'i', 'think', 'you', "'ll", 'find', 'helpful', '.'])
# (['what', "'ve", 'you', 'got', 'for', 'me', '?'], ['what', "'ve", 'you', 'got', 'for', 'me', '?'])
# (['yeah', '--', 'we', "'ll", 'see', '.'], ['yeah', '--', 'we', "'ll", 'see', '.'])
# (['and', 'he', 'means', 'that', 'strictly', 'in', 'a', 'non-', 'prison-movie', 'type', 'of', 'way', '.'], ['and', 'he', 'means', 'that', 'strictly', 'in', 'a', 'non-', 'prison-movie', 'type', 'of', 'way', '.'])
# (['and', 'why', 'would', 'i', 'do', 'that', '?'], ['and', 'why', 'would', 'i', 'do', 'that', '?'])
# (['leave', 'my', 'sister', 'alone', '.'], ['leave', 'my', 'sister', 'alone', '.'])
# (['your', 'sister', 'here', '?'], ['your', 'sister', 'here', '?'])
# (['away', '.'], ['away', '.'])
# (['where', 'ya', 'goin', '?'], ['where', 'ya', 'goin', '?'])
# (['not', 'at', 'all'], ['not', 'at', 'all'])
# (['hey', '--', 'do', 'you', 'mind', '?'], ['hey', '--', 'do', 'you', 'mind', '?'])
# (['they', "'re", 'running', 'rest', 'of', 'me', 'next', 'month', '.'], ['they', "'re", 'running', 'the', 'rest', 'of', 'me', 'next', 'month', '.'])
# (['enough', 'with', 'the', 'barbie', 'n', "'", 'ken', 'shit', '.', 'i', 'know', '.'], ['enough', 'with', 'the', 'barbie', 'n', "'", 'ken', 'shit', '.', 'i', 'know', '.'])
# (['get', 'her', 'act', 'like', 'a', 'human'], ['get', 'her', 'to', 'act', 'like', 'a', 'human'])
# (['do', 'what', '?'], ['do', 'what', '?'])
# (['how', "'d", 'you', 'do', 'it', '?'], ['how', "'d", 'you', 'do', 'it', '?'])
# (['a', 'deal', "'s", 'a', 'deal', '.'], ['a', 'deal', "'s", 'a', 'deal', '.'])
# (['it', "'s", 'about', 'time', '.'], ['it', "'s", 'about', 'time', '.'])
# (['forget', 'it', '.'], ['forget', 'it', '.'])
# (['hundred', 'bucks', 'a', 'date', '.'], ['a', 'hundred', 'bucks', 'a', 'date', '.'])
# (['what', '?'], ['what', '?'])
# (['i', 'just', 'upped', 'my', 'price'], ['i', 'just', 'upped', 'my', 'price'])
# (['i', 'got', 'her', 'under', 'control', '.', 'she', 'just', 'acts', 'crazed', 'in', 'public', 'keep', 'up', 'the', 'image', '.'], ['i', 'got', 'her', 'under', 'control', '.', 'she', 'just', 'acts', 'crazed', 'in', 'public', 'to', 'keep', 'up', 'the', 'image', '.'])
# (['watching', 'bitch', 'trash', 'my', 'car', 'does', "n't", 'count', 'as', 'a', 'date', '.'], ['watching', 'the', 'bitch', 'trash', 'my', 'car', 'does', "n't", 'count', 'as', 'a', 'date', '.'])
# (['i', 'on', 'it'], ['i', "'m", 'on', 'it'])
# (['take', 'it', 'or', 'leave', 'it', '.', 'this', 'is', "n't", 'negotiation', '.'], ['take', 'it', 'or', 'leave', 'it', '.', 'this', 'is', "n't", 'a', 'negotiation', '.'])
# (['i', 'ca', "n't", 'take', 'a', 'girl', 'like', 'that', 'out', 'on', 'twenty', 'bucks', '.'], ['i', 'ca', "n't", 'take', 'a', 'girl', 'like', 'that', 'out', 'on', 'twenty', 'bucks', '.'])
# (['how', 'much', '?'], ['how', 'much', '?'])
# (['i', 'ca', "n't", 'date', 'her', 'sister', 'until', 'that', 'one', 'gets', 'boyfriend', '.', 'and', 'that', "'s", 'the', 'catch', '.', 'she', 'does', "n't", 'want', 'boyfriend', '.'], ['i', 'ca', "n't", 'date', 'her', 'sister', 'until', 'that', 'one', 'gets', 'a', 'boyfriend', '.', 'and', 'that', "'s", 'the', 'catch', '.', 'she', 'does', "n't", 'want', 'a', 'boyfriend', '.'])
# (['you', "'re", 'gon', 'na', 'pay', 'me', 'take', 'out', 'some', 'girl', '?'], ['you', "'re", 'gon', 'na', 'pay', 'me', 'to', 'take', 'out', 'some', 'girl', '?'])
# (['but', 'you', "'d", 'go', 'out', 'with', 'her', 'if', 'you', 'had', 'the', 'cake', '?'], ['but', 'you', "'d", 'go', 'out', 'with', 'her', 'if', 'you', 'had', 'the', 'cake', '?'])
# (['you', 'need', 'money', 'to', 'take', 'girl', 'out'], ['you', 'need', 'money', 'to', 'take', 'a', 'girl', 'out'])
# (['you', 'just', 'said'], ['you', 'just', 'said'])
# (['what', 'do', 'you', 'think', '?'], ['what', 'do', 'you', 'think', '?'])
# (['yeah'], ['yeah'])
# (['hey', '--', 'it', 'all', 'for', 'the', 'higher', 'good', 'right', '?'], ['hey', '--', 'it', "'s", 'all', 'for', 'the', 'higher', 'good', 'right', '?'])
# (['you', 'better', 'not', 'fuck', 'this', 'up', '.', 'i', "'m", 'heavily', 'invested', '.'], ['you', 'better', 'not', 'fuck', 'this', 'up', '.', 'i', "'m", 'heavily', 'invested', '.'])
# (['what', '?', 'we', 'took', 'bathes', 'together', 'when', 'we', 'were', 'kids', '.'], ['what', '?', 'we', 'took', 'bathes', 'together', 'when', 'we', 'were', 'kids', '.'])
# (['you', 'and', 'verona', '?'], ['you', 'and', 'verona', '?'])
# (['i', 'hear', 'you', "'re", 'helpin', "'", 'verona', '.'], ['i', 'hear', 'you', "'re", 'helpin', "'", 'verona', '.'])
# (['so', 'what', 'you', 'need', 'to', 'do', 'is', 'recruit', 'guy', 'who', "'ll", 'go', 'out', 'with', 'her', '.', 'someone', 'who', 'up', 'for', 'job', '.'], ['so', 'what', 'you', 'need', 'to', 'do', 'is', 'recruit', 'a', 'guy', 'who', "'ll", 'go', 'out', 'with', 'her', '.', 'someone', 'who', "'s", 'up', 'for', 'the', 'job', '.'])
# (['does', 'this', 'conversation', 'have', 'purpose', '?'], ['does', 'this', 'conversation', 'have', 'a', 'purpose', '?'])
# (['but', 'she', 'ca', "n't", 'go', 'out', 'with', 'you', 'because', 'her', 'sister', 'is', 'this', 'insane', 'head', 'case', 'and', 'no', 'one', 'will', 'go', 'out', 'with', 'her', '.', 'right', '?'], ['but', 'she', 'ca', "n't", 'go', 'out', 'with', 'you', 'because', 'her', 'sister', 'is', 'this', 'insane', 'head', 'case', 'and', 'no', 'one', 'will', 'go', 'out', 'with', 'her', '.', 'right', '?'])
# (['we', "'re", 'not', '.'], ['we', "'re", 'not', '.'])
# (['we', 'do', "n't", 'chat', '.'], ['we', 'do', "n't", 'chat', '.'])
# (['nope', '-', 'just', 'came', 'by', 'chat'], ['nope', '-', 'just', 'came', 'by', 'to', 'chat'])
# (['are', 'you', 'lost', '?'], ['are', 'you', 'lost', '?'])
# (['hey', '.'], ['hey', '.'])
# (['william', '-', 'he', 'asked', 'me', 'to', 'meet', 'him', 'here', '.'], ['william', '-', 'he', 'asked', 'me', 'to', 'meet', 'him', 'here', '.'])
# (['who', '?'], ['who', '?'])
# (['have', 'you', 'seen', 'him', '?'], ['have', 'you', 'seen', 'him', '?'])
# (['you', "'", 're', 'looking', 'at', 'this', 'from', 'the', 'wrong', 'perspective', '.', 'we', "'re", 'making', 'statement', '.'], ['you', "'", 're', 'looking', 'at', 'this', 'from', 'the', 'wrong', 'perspective', '.', 'we', "'re", 'making', 'a', 'statement', '.'])
# (['can', 'you', 'even', 'imagine', '?', 'who', 'the', 'hell', 'would', 'go', 'this', 'bastion', 'of', 'commercial', 'excess', '?'], ['can', 'you', 'even', 'imagine', '?', 'who', 'the', 'hell', 'would', 'go', 'to', 'this', 'a', 'bastion', 'of', 'commercial', 'excess', '?'])
# (['i', 'got', 'drunk', '.', 'i', 'puked', '.', 'i', 'got', 'rejected', '.', 'it', 'was', 'big', 'fun', '.'], ['i', 'got', 'drunk', '.', 'i', 'puked', '.', 'i', 'got', 'rejected', '.', 'it', 'was', 'big', 'fun', '.'])
# (['you', 'did', "n't"], ['you', 'did', "n't"])
# (['i', 'did', 'bianca', 'favor', 'and', 'it', 'backfired', '.'], ['i', 'did', 'bianca', 'a', 'favor', 'and', 'it', 'backfired', '.'])
# (['you', 'did', "n't", 'have', 'choice', '?', 'where', 'kat', 'and', 'what', 'have', 'you', 'done', 'with', 'her', '?'], ['you', 'did', "n't", 'have', 'a', 'choice', '?', 'where', "'s", 'kat', 'and', 'what', 'have', 'you', 'done', 'with', 'her', '?'])
# (['i', 'did', "n't", 'have', 'choice', '.'], ['i', 'did', "n't", 'have', 'a', 'choice', '.'])
# (['you', 'went', 'the', 'party', '?', 'i', 'thought', 'we', 'were', 'officially', 'opposed', 'to', 'suburban', 'social', 'activity', '.'], ['you', 'went', 'to', 'the', 'party', '?', 'i', 'thought', 'we', 'were', 'officially', 'opposed', 'to', 'suburban', 'social', 'activity', '.'])
# (['who', 'cares', '?'], ['who', 'cares', '?'])
# (['what', "'d", 'he', 'say', '?'], ['what', "'d", 'he', 'say', '?'])
# (['no', 'fear', '.'], ['no', 'fear', '.'])
# (['you', 'think', 'this', 'work', '?'], ['you', 'think', 'this', "'ll", 'work', '?'])
# (['does', 'it', 'matter', '?'], ['does', 'it', 'matter', '?'])
# (['neither', 'has', 'his', 'heterosexuality', '.'], ['neither', 'has', 'his', 'heterosexuality', '.'])
# (['that', 'never', 'been', 'proven'], ['that', "'s", 'never', 'been', 'proven'])
# (['william', 'did', "n't", 'even', 'go', 'to', 'high', 'school'], ['william', 'did', "n't", 'even', 'go', 'to', 'high', 'school'])
# (['william', 'would', 'never', 'have', 'gone', 'a', 'state', 'school', '.'], ['william', 'would', 'never', 'have', 'gone', 'to', 'a', 'state', 'school', '.'])
# (['you', 'could', 'always', 'go', 'with', 'me', '.', 'i', "'m", 'sure', 'william', 'has', 'some', 'friends', '.'], ['you', 'could', 'always', 'go', 'with', 'me', '.', 'i', "'m", 'sure', 'william', 'has', 'some', 'friends', '.'])
# (['the', 'people', 'at', 'this', 'school', 'are', 'so', 'incredibly', 'foul', '.'], ['the', 'people', 'at', 'this', 'school', 'are', 'so', 'incredibly', 'foul', '.'])
# (['but', 'imagine', 'the', 'things', 'he', "'d", 'say', 'during', 'sex', '.'], ['but', 'imagine', 'the', 'things', 'he', "'d", 'say', 'during', 'sex', '.'])
# (['an', 'attempted', 'slit', '.'], ['an', 'attempted', 'slit', '.'])
# (['what', "'s", 'this', '?'], ['what', "'s", 'this', '?'])
# (['just', 'little', '.'], ['just', 'a', 'little', '.'])
# (['block', 'e', '?'], ['block', 'e', '?'])
# (['he', 'always', 'look', 'so'], ['he', 'always', 'look', 'so'])
# (['i', "'m", 'sure', 'he', "'s", 'completely', 'incapable', 'of', 'doing', 'anything', 'that', 'interesting', '.'], ['i', "'m", 'sure', 'he', "'s", 'completely', 'incapable', 'of', 'doing', 'anything', 'that', 'interesting', '.'])
# (['that', "'s", 'pat', 'verona', '?', 'the', 'one', 'who', 'was', 'gone', 'for', 'year', '?', 'i', 'heard', 'he', 'was', 'doing', 'porn', 'movies', '.'], ['that', "'s", 'pat', 'verona', '?', 'the', 'one', 'who', 'was', 'gone', 'for', 'a', 'year', '?', 'i', 'heard', 'he', 'was', 'doing', 'porn', 'movies', '.'])
# (['patrick', 'verona', 'random', 'skid', '.'], ['patrick', 'verona', 'random', 'skid', '.'])
# (['who', 'that', '?'], ['who', "'s", 'that', '?'])
# (['don', "'", 't', 'you', 'even', 'dare', '.', '.', '.'], ['don', "'", 't', 'you', 'even', 'dare', '.', '.', '.'])
# (['because', 'i', 'like', 'to', 'torture', 'you', '.'], ['because', 'i', 'like', 'to', 'torture', 'you', '.'])
# (['why', 'is', 'my', 'veggie', 'burger', 'the', 'only', 'burnt', 'object', 'on', 'this', 'grill', '?'], ['why', 'is', 'my', 'veggie', 'burger', 'the', 'only', 'burnt', 'object', 'on', 'this', 'grill', '?'])
# (['is', 'that', 'right', '?'], ['is', 'that', 'right', '?'])
# (['i', 'thought', 'you', 'could', 'use', 'it', '.', 'when', 'you', 'start', 'your', 'band', '.'], ['i', 'thought', 'you', 'could', 'use', 'it', '.', 'when', 'you', 'start', 'your', 'band', '.'])
# (['a', 'fender', 'strat', '.', 'you', 'bought', 'this', '?'], ['a', 'fender', 'strat', '.', 'you', 'bought', 'this', '?'])
# (['i', 'did', "n't", 'care', 'about', 'the', 'money', '.'], ['i', 'did', "n't", 'care', 'about', 'the', 'money', '.'])
# (['it', 'was', "n't", 'like', 'that', '.'], ['it', 'was', "n't", 'like', 'that', '.'])
# (['you', 'were', 'paid', 'take', 'me', 'out', '!', 'by', '--', 'one', 'person', 'i', 'truly', 'hate', '.', 'i', 'knew', 'it', 'was', 'set-up', '!'], ['you', 'were', 'paid', 'to', 'take', 'me', 'out', '!', 'by', '--', 'the', 'one', 'person', 'i', 'truly', 'hate', '.', 'i', 'knew', 'it', 'was', 'a', 'set-up', '!'])
# (['wait', 'i', '...'], ['wait', 'i', '...'])
# (['it', 'gets', 'worse', '--', 'you', 'still', 'have', 'your', 'freshman', 'yearbook', '?'], ['it', 'gets', 'worse', '--', 'you', 'still', 'have', 'your', 'freshman', 'yearbook', '?'])
# (['that', "'", 's', 'completely', 'adorable', '!'], ['that', "'", 's', 'completely', 'adorable', '!'])
# (['what', '?'], ['what', '?'])
# (['my', 'grandmother', "'s", '.'], ['my', 'grandmother', "'s", '.'])
# (['oh', 'huh'], ['oh', 'huh'])
# (['it', "'s", 'just', 'something', 'i', 'had', '.', 'you', 'know'], ['it', "'s", 'just', 'something', 'i', 'had', '.', 'you', 'know'])
# (['it', "'s", 'scurvy', "'s", '.', 'his', 'date', 'got', 'convicted', '.', 'where', "'d", 'you', 'get', 'dress', '?'], ['it', "'s", 'scurvy', "'s", '.', 'his', 'date', 'got', 'convicted', '.', 'where', "'d", 'you', 'get', 'the', 'dress', '?'])
# (['how', "'d", 'you', 'get', 'a', 'tux', 'at', 'the', 'last', 'minute', '?'], ['how', "'d", 'you', 'get', 'a', 'tux', 'at', 'the', 'last', 'minute', '?'])
# (['nothing', '!', 'there', "'s", 'nothing', 'in', 'it', 'for', 'me', '.', 'just', 'the', 'pleasure', 'of', 'your', 'company', '.'], ['nothing', '!', 'there', "'s", 'nothing', 'in', 'it', 'for', 'me', '.', 'just', 'the', 'pleasure', 'of', 'your', 'company', '.'])
# (['you', 'need', 'therapy', '.', 'has', 'anyone', 'ever', 'told', 'you', 'that', '?'], ['you', 'need', 'therapy', '.', 'has', 'anyone', 'ever', 'told', 'you', 'that', '?'])
# (['you', 'tell', 'me', '.'], ['you', 'tell', 'me', '.'])
# (['so', 'i', 'have', 'to', 'have', 'motive', 'to', 'be', 'with', 'you', '?'], ['so', 'i', 'have', 'to', 'have', 'a', 'motive', 'to', 'be', 'with', 'you', '?'])
# (['create', 'little', 'drama', '?', 'start', 'new', 'rumor', '?', 'what', '?'], ['create', 'a', 'little', 'drama', '?', 'start', 'a', 'new', 'rumor', '?', 'what', '?'])
# (['because', 'i', 'do', "n't", 'want', 'to', '.', 'it', "'s", 'stupid', 'tradition', '.'], ['because', 'i', 'do', "n't", 'want', 'to', '.', 'it', "'s", 'a', 'stupid', 'tradition', '.'])
# (['why', 'not', '?'], ['why', 'not', '?'])
# (['no', 'what', '?'], ['no', 'what', '?'])
# (['no', '.'], ['no', '.'])
# (['you', 'know', 'what', 'i', 'mean'], ['you', 'know', 'what', 'i', 'mean'])
# (['is', 'that', 'request', 'or', 'command', '?'], ['is', 'that', 'a', 'request', 'or', 'a', 'command', '?'])
# (['go', 'the', 'prom', 'with', 'me'], ['go', 'to', 'the', 'prom', 'with', 'me'])
# (['you', "'re", 'amazingly', 'self-assured', '.', 'has', 'anyone', 'ever', 'told', 'you', 'that', '?'], ['you', "'re", 'amazingly', 'self-assured', '.', 'has', 'anyone', 'ever', 'told', 'you', 'that', '?'])
# (['no', 'one', 'else', 'knows'], ['no', 'one', 'else', 'knows'])
# (['what', '?'], ['what', '?'])
# (['you', "'re", 'sweet', '.', 'and', 'sexy', '.', 'and', 'completely', 'hot', 'for', 'me', '.'], ['you', "'re", 'sweet', '.', 'and', 'sexy', '.', 'and', 'completely', 'hot', 'for', 'me', '.'])
# (['no', '--', 'something', 'real', '.', 'something', 'no', 'one', 'else', 'knows', '.'], ['no', '--', 'something', 'real', '.', 'something', 'no', 'one', 'else', 'knows', '.'])
# (['i', 'hate', 'peas', '.'], ['i', 'hate', 'peas', '.'])
# (['tell', 'me', 'something', 'true', '.'], ['tell', 'me', 'something', 'true', '.'])
# (['i', 'know', 'porn', 'career', 'a', 'lie', '.'], ['i', 'know', 'the', 'porn', 'career', "'s", 'a', 'lie', '.'])
# (['hearsay', '.'], ['hearsay', '.'])
# (['the', 'duck', '?'], ['the', 'duck', '?'])
# (['fallacy', '.'], ['fallacy', '.'])
# (['state', 'trooper', '?'], ['state', 'trooper', '?'])
# (['for', '.', '.', '.', '?'], ['for', '.', '.', '.', '?'])
# (['you', 'up', 'for', 'it', '?'], ['you', 'up', 'for', 'it', '?'])
# (['you', 'never', 'disappointed', 'me', '.'], ['you', 'never', 'disappointed', 'me', '.'])
# (['how', '?'], ['how', '?'])
# (['then', 'you', 'screwed', 'up'], ['then', 'you', 'screwed', 'up'])
# (['something', 'like', 'that'], ['something', 'like', 'that'])
# (['i', 'do', "n't", 'like', 'do', 'what', 'people', 'expect', '.', 'then', 'they', 'expect', 'it', 'all', 'the', 'time', 'and', 'they', 'get', 'disappointed', 'when', 'you', 'change', '.'], ['i', 'do', "n't", 'like', 'to', 'do', 'what', 'people', 'expect', '.', 'then', 'they', 'expect', 'it', 'all', 'the', 'time', 'and', 'they', 'get', 'disappointed', 'when', 'you', 'change', '.'])
# (['yes'], ['yes'])
# (['acting', 'way', 'we', 'do', '.'], ['acting', 'the', 'way', 'we', 'do', '.'])
# (['so', 'what', "'s", 'your', 'excuse', '?'], ['so', 'what', "'s", 'your', 'excuse', '?'])
# (['a', 'soft', 'side', '?', 'who', 'knew', '?'], ['a', 'soft', 'side', '?', 'who', 'knew', '?'])
# (['i', 'dazzled', 'him', 'with', 'my', 'wit'], ['i', 'dazzled', 'him', 'with', 'my', 'wit'])
# (['so', 'how', "'d", 'you', 'get', 'chapin', 'look', 'other', 'way', '?'], ['so', 'how', "'d", 'you', 'get', 'chapin', 'to', 'look', 'the', 'other', 'way', '?'])
# (['good', 'call', '.'], ['good', 'call', '.'])
# (['i', 'figured', 'it', 'had', 'be', 'something', 'ridiculous', 'to', 'win', 'your', 'respect', '.', 'and', 'piss', 'you', 'off', '.'], ['i', 'figured', 'it', 'had', 'to', 'be', 'something', 'ridiculous', 'to', 'win', 'your', 'respect', '.', 'and', 'piss', 'you', 'off', '.'])
# (['the', 'partridge', 'family', '?'], ['the', 'partridge', 'family', '?'])
# (['maybe', '.'], ['maybe', '.'])
# (['you', 'want', 'me', 'to', 'climb', 'up', 'and', 'show', 'you', 'how', 'to', 'get', 'down', '?'], ['you', 'want', 'me', 'to', 'climb', 'up', 'and', 'show', 'you', 'how', 'to', 'get', 'down', '?'])
# (['forget', 'it', '.', 'i', 'stayin', "'", '.'], ['forget', 'it', '.', 'i', "'m", 'stayin', "'", '.'])
# (['put', 'your', 'right', 'foot', 'their', '--'], ['put', 'your', 'right', 'foot', 'there', '--'])
# (['try', 'lookin', "'", 'at', 'it', 'from', 'this', 'angle'], ['try', 'lookin', "'", 'at', 'it', 'from', 'this', 'angle'])
# (["c'mon", '.', 'it', 'not', 'that', 'bad'], ["c'mon", '.', 'it', "'s", 'not', 'that', 'bad'])
# (['i', 'guess', 'i', 'never', 'told', 'you', 'i', 'afraid', 'of', 'heights', '.'], ['i', 'guess', 'i', 'never', 'told', 'you', 'i', "'m", 'afraid', 'of', 'heights', '.'])
# (['he', 'left', '!', 'i', 'sprung', 'the', 'dickhead', 'and', 'he', 'cruised', 'on', 'me', '.'], ['he', 'left', '!', 'i', 'sprung', 'the', 'dickhead', 'and', 'he', 'cruised', 'on', 'me', '.'])
# (['other', 'then', 'my', 'upchuck', 'reflex', '?', 'nothing', '.'], ['other', 'than', 'my', 'upchuck', 'reflex', '?', 'nothing', '.'])
# (['so', 'what', 'did', 'i', 'have', 'an', 'effect', 'on', '?'], ['so', 'what', 'did', 'i', 'have', 'an', 'effect', 'on', '?'])
# (['do', "n't", 'for', 'one', 'minute', 'think', 'that', 'you', 'had', 'any', 'effect', 'whatsoever', 'on', 'my', 'panties', '.'], ['do', "n't", 'for', 'one', 'minute', 'think', 'that', 'you', 'had', 'any', 'effect', 'whatsoever', 'on', 'my', 'panties', '.'])
# (['unwelcome', '?', 'i', 'guess', 'someone', 'still', 'has', 'her', 'panties', 'in', 'a', 'twist', '.'], ['unwelcome', '?', 'i', 'guess', 'someone', 'still', 'has', 'her', 'panties', 'in', 'a', 'twist', '.'])
# (['unwelcome', '.'], ['unwelcome', '.'])
# (['wholesome', '.'], ['wholesome', '.'])
# (['pleasant', '?'], ['pleasant', '?'])
# (['you', "'re", 'so', '--'], ['you', "'re", 'so', '--'])
# (['i', 'heard', 'their', 'was', 'poetry', 'reading', '.'], ['i', 'heard', 'there', 'was', 'a', 'poetry', 'reading', '.'])
# (['what', 'are', 'you', 'doing', 'here', '?'], ['what', 'are', 'you', 'doing', 'here', '?'])
# (['bianca'], ['bianca'])
# (['who', '?'], ['who', '?'])
# (['he', 'just', 'wants', 'me', 'be', 'someone', 'i', "'m", 'not', '.'], ['he', 'just', 'wants', 'me', 'to', 'be', 'someone', 'i', "'m", 'not', '.'])
# (['so', 'what', "'", 's', 'up', 'with', 'your', 'dad', '?', 'he', 'pain', 'in', 'the', 'ass', '?'], ['so', 'what', "'", 's', 'up', 'with', 'your', 'dad', '?', 'he', 'a', 'pain', 'in', 'the', 'ass', '?'])
# (['i', "'m", 'gettin', "'", 'there'], ['i', "'m", 'gettin', "'", 'there'])
# (['you', 'do', "n't", 'strike', 'me', 'as', 'the', 'type', 'that', 'would', 'ask', 'permission', '.'], ['you', 'do', "n't", 'strike', 'me', 'as', 'the', 'type', 'that', 'would', 'ask', 'permission', '.'])
# (['my', 'father', 'would', "n't", 'approve', 'of', 'that', 'that'], ['my', 'father', 'would', "n't", 'approve', 'of', 'that', 'that'])
# (['start', 'a', 'band', '?'], ['start', 'a', 'band', '?'])
# (['this', '.'], ['this', '.'])
# (['do', 'what', '?'], ['do', 'what', '?'])
# (['i', 'should', 'do', 'this', '.'], ['i', 'should', 'do', 'this', '.'])
# (['why', "'d", 'you', 'lie', '?'], ['why', "'d", 'you', 'lie', '?'])
# (['then', 'why', "'d", 'you', 'ask', '?'], ['then', 'why', "'d", 'you', 'ask', '?'])
# (['maybe', '.'], ['maybe', '.'])
# (['were', 'you', 'in', 'jail', '?'], ['were', 'you', 'in', 'jail', '?'])
# (['busy'], ['busy'])
# (['when', 'you', 'were', 'gone', 'last', 'year', '--', 'where', 'were', 'you', '?'], ['when', 'you', 'were', 'gone', 'last', 'year', '--', 'where', 'were', 'you', '?'])
# (['but', 'it', "'s", 'gigglepuss', '-', 'i', 'know', 'you', 'like', 'them', '.', 'i', 'saw', 'you', 'their', '.'], ['but', 'it', "'s", 'gigglepuss', '-', 'i', 'know', 'you', 'like', 'them', '.', 'i', 'saw', 'you', 'there', '.'])
# (['and', 'i', 'in', 'control', 'of', 'it', '.'], ['and', 'i', "'m", 'in', 'control', 'of', 'it', '.'])
# (['what', '?'], ['what', '?'])
# (['kat', '!', 'wake', 'up', '!'], ['kat', '!', 'wake', 'up', '!'])
# (['you', 'know', 'what', 'they', 'say'], ['you', 'know', 'what', 'they', 'say'])
# (['i', 'thought', 'you', 'were', 'above', 'all', 'that'], ['i', 'thought', 'you', 'were', 'above', 'all', 'that'])
# (['hey', 'man', '.', '.', '.', 'you', 'don', "'", 't', 'think', 'i', 'can', 'be', '``', 'cool', "''", '?', 'you', 'do', "n't", 'think', 'i', 'can', 'be', '``', 'laid', 'back', "''", 'like', 'everyone', 'else', '?'], ['hey', 'man', '.', '.', '.', 'you', 'don', "'", 't', 'think', 'i', 'can', 'be', '``', 'cool', "''", '?', 'you', 'do', "n't", 'think', 'i', 'can', 'be', '``', 'laid', 'back', "''", 'like', 'everyone', 'else', '?'])
# (['i', 'know', '.', 'it', "'d", 'have', 'to', 'be', 'a', 'pretty', 'big', 'deal', 'to', 'get', 'you', 'mainline', 'tequila', '.', 'you', 'do', "n't", 'seem', 'like', 'type', '.'], ['i', 'know', '.', 'it', "'d", 'have', 'to', 'be', 'a', 'pretty', 'big', 'deal', 'to', 'get', 'you', 'to', 'mainline', 'tequila', '.', 'you', 'do', "n't", 'seem', 'like', 'the', 'type', '.'])
# (['i', 'hate', 'him', '.'], ['i', 'hate', 'him', '.'])
# (['dorsey', '.'], ['dorsey', '.'])
# (['who', '?'], ['who', '?'])
# (['why', "'d", 'you', 'let', 'him', 'get', 'you', '?'], ['why', "'d", 'you', 'let', 'him', 'get', 'to', 'you', '?'])
# (['just', 'let', 'me', 'sit', 'down', '.'], ['just', 'let', 'me', 'sit', 'down', '.'])
# (['see', 'that', '?', 'who', 'needs', 'affection', 'when', 'i', "'ve", 'got', 'blind', 'hatred', '?'], ['see', 'that', '?', 'who', 'needs', 'affection', 'when', 'i', "'ve", 'got', 'blind', 'hatred', '?'])
# (['like', 'you', 'could', 'find', 'one'], ['like', 'you', 'could', 'find', 'one'])
# (['because', 'then', 'i', "'d", 'have', 'to', 'start', 'taking', 'out', 'girls', 'who', 'like', 'me', '.'], ['because', 'then', 'i', "'d", 'have', 'to', 'start', 'taking', 'out', 'girls', 'who', 'like', 'me', '.'])
# (['why', '?'], ['why', '?'])
# (['you', 'do', "n't", 'care', 'if', 'i', 'die'], ['you', 'do', "n't", 'care', 'if', 'i', 'die'])
# (['i', 'told', 'you'], ['i', 'told', 'you'])
# ...
# (['tool', '?', 'tool', 'for', 'what', '?', 'we', "'ve", 'been', 'going', 'together', 'almost', 'two', 'years', '!'], ['tool', '?', 'tool', 'for', 'what', '?', 'we', "'ve", 'been', 'going', 'together', 'almost', 'two', 'years', '!'])
# (['brad', '.', 'i', 'do', "n't", 'want', 'have', 'to', 'use', 'sex', 'as', 'tool', '.'], ['brad', '.', 'i', 'do', "n't", 'want', 'to', 'have', 'to', 'use', 'sex', 'as', 'a', 'tool', '.'])
# (['do', "n't", 'worry', 'about', 'it', '.'], ['do', "n't", 'worry', 'about', 'it', '.'])
# (['how', 'much', 'did', 'they', 'cost', '?'], ['how', 'much', 'did', 'they', 'cost', '?'])
# (['of', 'course', '.'], ['of', 'course', '.'])
# (['later', '.'], ['later', '.'])
# (['there', 'it', 'is', '!'], ['there', 'it', 'is', '!'])
# (['first', 'door', 'on', 'your', 'left', '!'], ['first', 'door', 'on', 'your', 'left', '!'])
# (['on', 'ledge', '?'], ['on', 'the', 'ledge', '?'])
# (['it', "'s", 'the', 'first', 'door', 'on', 'your', 'left', '!'], ['it', "'s", 'the', 'first', 'door', 'on', 'your', 'left', '!'])
# (['it', 'first', 'door', 'on', 'your', 'left', '.'], ['it', "'s", 'the', 'first', 'door', 'on', 'your', 'left', '.'])
# (['totally', '.'], ['totally', '.'])
# (['go', 'ahead', '.', 'just', 'make', 'it', 'quick', '.'], ['go', 'ahead', '.', 'just', 'make', 'it', 'quick', '.'])
# (['you', 'really', 'want', 'me', 'to', 'put', 'all', 'this', 'stuff', 'back', 'on', '?'], ['you', 'really', 'want', 'me', 'to', 'put', 'all', 'this', 'stuff', 'back', 'on', '?'])
# (['i', 'thought', 'i', "'d", 'take', 'it', 'off', 'for', 'the', 'drive', 'over', 'to', 'ibm', '.', 'it', "'s", 'kind', 'of', 'uncomfortable', '.'], ['i', 'thought', 'i', "'d", 'take', 'it', 'off', 'for', 'the', 'drive', 'over', 'to', 'ibm', '.', 'it', "'s", 'kind', 'of', 'uncomfortable', '.'])
# (['but', 'you', 'took', 'off', 'your', 'captain', 'kidd', 'uniform', '.'], ['but', 'you', 'took', 'off', 'your', 'captain', 'kidd', 'uniform', '.'])
# (['this', 'is', 'how', 'i', 'dress', 'all', 'time', '.'], ['this', 'is', 'how', 'i', 'dress', 'all', 'the', 'time', '.'])
# (['manager', '!', '!'], ['manager', '!', '!'])
# (['i', 'am', 'so', 'tired', '.', 'i', 'am', 'so', 'tired', 'of', 'dealing', 'with', 'morons', '.', 'how', 'hard', 'is', 'it', '...'], ['i', 'am', 'so', 'tired', '.', 'i', 'am', 'so', 'tired', 'of', 'dealing', 'with', 'morons', '.', 'how', 'hard', 'is', 'it', 'to', '...'])
# (['i', 'ca', "n't", 'do', 'that', '.', 'but', 'if', 'you', 'wait', 'a', 'minute', '...'], ['i', 'ca', "n't", 'do', 'that', '.', 'but', 'if', 'you', 'wait', 'a', 'minute', '...'])
# (['see', 'that', 'sign', '?', 'it', 'says', '100', '%', 'money', 'back', 'guarantee', '.', 'do', 'you', 'know', 'meaning', 'of', 'the', 'word', "'guarantee", "'", '?', 'do', 'they', 'teach', 'you', 'that', 'here', '?', 'give', 'me', 'my', 'money', 'back', '.'], ['see', 'that', 'sign', '?', 'it', 'says', '100', '%', 'money', 'back', 'guarantee', '.', 'do', 'you', 'know', 'the', 'meaning', 'of', 'the', 'word', "'guarantee", "'", '?', 'do', 'they', 'teach', 'you', 'that', 'here', '?', 'give', 'me', 'my', 'money', 'back', '.'])
# (['no', '.', 'i', 'want', 'my', 'money', 'back', 'right', 'now', '.'], ['no', '.', 'i', 'want', 'my', 'money', 'back', 'right', 'now', '.'])
# (['no', '.'], ['no', '.'])
# (['brad', '.', 'please', 'do', "n't", 'tell', 'mom', 'and', 'dad', '...'], ['brad', '.', 'please', 'do', "n't", 'tell', 'mom', 'and', 'dad', '...'])
# (['since', 'when', 'do', 'you', 'shop', 'at', 'flea', 'market', 'anyway', '?'], ['since', 'when', 'do', 'you', 'shop', 'at', 'the', 'flea', 'market', 'anyway', '?'])
# (['see', 'you', 'later', '.'], ['see', 'you', 'later', '.'])
# (['yeah', '.', 'this', 'is', 'it', '.', 'i', 'have', 'some', 'shopping', 'to', 'do', '.'], ['yeah', '.', 'this', 'is', 'it', '.', 'i', 'have', 'some', 'shopping', 'to', 'do', '.'])
# (['it', 'just', 'linda', '.', 'and', 'mark', 'from', 'school', '.'], ['it', "'s", 'just', 'linda', '.', 'and', 'mark', 'from', 'school', '.'])
# (['does', 'mom', 'know', 'you', 'have', 'company', '?'], ['does', 'mom', 'know', 'you', 'have', 'company', '?'])
# (['do', "n't", 'give', 'me', 'that', 'shit', '!', 'i', 'know', 'you', "'re", 'still', 'a', 'virgin', '!'], ['do', "n't", 'give', 'me', 'that', 'shit', '!', 'i', 'know', 'you', "'re", 'still', 'a', 'virgin', '!'])
# (['maybe', 'yes', '.', 'maybe', 'no', '.'], ['maybe', 'yes', '.', 'maybe', 'no', '.'])
# (['are', 'you', 'still', 'a', 'virgin', '?'], ['are', 'you', 'still', 'a', 'virgin', '?'])
# (['but', 'your', 'face', 'did', '!'], ['but', 'your', 'face', 'did', '!'])
# (['i', 'did', "n't", 'say', 'that', '.'], ['i', 'did', "n't", 'say', 'that', '.'])
# (['you', 'are', 'virgin', '!'], ['you', 'are', 'a', 'virgin', '!'])
# (['maybe', 'yes', '.', 'maybe', 'no', '.'], ['maybe', 'yes', '.', 'maybe', 'no', '.'])
# (['i', 'do', "n't", 'know', '.', 'i', 'was', 'just', 'curious', '.'], ['i', 'do', "n't", 'know', '.', 'i', 'was', 'just', 'curious', '.'])
# (['why', '?'], ['why', '?'])
# (['everybody', 'loves', 'lisa', '.', 'everybody', 'loves', 'lisa', '.', 'but', 'everybody', 'does', "n't", 'have', 'be', 'her', 'boyfriend', '.'], ['everybody', 'loves', 'lisa', '.', 'everybody', 'loves', 'lisa', '.', 'but', 'everybody', 'does', "n't", 'have', 'to', 'be', 'her', 'boyfriend', '.'])
# (['well', '...', 'it', "'s", 'true', '.'], ['well', '...', 'it', "'s", 'true', '.'])
# (['i', 'just', 'guessing', '.'], ['i', "'m", 'just', 'guessing', '.'])
# (['where', 'did', 'you', 'hear', 'that', '?'], ['where', 'did', 'you', 'hear', 'that', '?'])
# (['why', '?', 'because', 'she', 'wo', "n't", 'sleep', 'with', 'you', '?'], ['why', '?', 'because', 'she', 'wo', "n't", 'sleep', 'with', 'you', '?'])
# (['are', 'you', 'kidding', '?', 'work', 'is', 'great', '.', 'i', 'kill', 'at', 'work', '.', 'i', 'do', "n't", 'even', 'mind', 'mom', 'and', 'dad', 'making', 'me', 'pay', 'rent', '.'], ['are', 'you', 'kidding', '?', 'work', 'is', 'great', '.', 'i', 'kill', 'at', 'work', '.', 'i', 'do', "n't", 'even', 'mind', 'mom', 'and', 'dad', 'making', 'me', 'pay', 'rent', '.'])
# (['is', 'everything', 'okay', 'at', 'work', '?'], ['is', 'everything', 'okay', 'at', 'work', '?'])
# (['i', 'do', "n't", 'care', 'it', 'you', 'tell', 'me', 'or', 'not', '.', 'i', 'got', 'problems', 'of', 'my', 'own', '.'], ['i', 'do', "n't", 'care', 'it', 'you', 'tell', 'me', 'or', 'not', '.', 'i', 'got', 'problems', 'of', 'my', 'own', '.'])
# (['it', 'just', 'some', 'guy', 'i', 'met', 'at', 'swenson', '.', 'you', 'do', "n't", 'know', 'him', '.'], ['it', "'s", 'just', 'some', 'guy', 'i', 'met', 'at', 'swenson', "'s", '.', 'you', 'do', "n't", 'know', 'him', '.'])
# (['do', "n't", 'worry', 'about', 'it', '.', 'who', 'sent', 'the', 'flowers', '?'], ['do', "n't", 'worry', 'about', 'it', '.', 'who', 'sent', 'the', 'flowers', '?'])
# (['thanks', 'for', 'getting', 'rid', 'of', 'those', 'flowers', '.'], ['thanks', 'for', 'getting', 'rid', 'of', 'those', 'flowers', '.'])
# (['i', "'ll", 'explain', 'everything', 'later', '.'], ['i', "'ll", 'explain', 'everything', 'later', '.'])
# (['i', "'d", 'say', '...', 'who', 'hell', 'is', 'ron', 'johnson', '?'], ['i', "'d", 'say', '...', 'who', 'the', 'hell', 'is', 'ron', 'johnson', '?'])
# (['they', "'re", 'not', 'home', 'yet', '.'], ['they', "'re", 'not', 'home', 'yet', '.'])
# (['brad', '!', 'have', 'mom', 'or', 'dad', 'seen', 'this', '?'], ['brad', '!', 'have', 'mom', 'or', 'dad', 'seen', 'this', '?'])
# (['do', "n't", 'strain', 'yourself', '.'], ['do', "n't", 'strain', 'yourself', '.'])
# (['i', 'take', 'out', 'the', 'garbage', '.'], ['i', 'take', 'out', 'the', 'garbage', '.'])
# (['your', 'friends', 'use', 'the', 'pool', 'too', '.'], ['your', 'friends', 'use', 'the', 'pool', 'too', '.'])
# (['your', 'friends', 'use', 'pool', '.', 'your', 'friends', 'messed', 'it', 'up', '.'], ['your', 'friends', 'use', 'the', 'pool', '.', 'your', 'friends', 'messed', 'it', 'up', '.'])
# (['why', 'ca', "n't", 'you', 'do', 'it', '?'], ['why', 'ca', "n't", 'you', 'do', 'it', '?'])
# (['mom', 'says', 'to', 'clean', 'up', 'the', 'pool', '.'], ['mom', 'says', 'to', 'clean', 'up', 'the', 'pool', '.'])
# (['hey-yo', '.'], ['hey-yo', '.'])
# (['u.s.', 'history', '.', 'mr.', 'hand', '.'], ['u.s.', 'history', '.', 'mr.', 'hand', '.'])
# (['everyone', 'wants', 'to', 'know', 'where', 'lisa', 'is', '.', 'how', 'should', 'i', 'know', 'where', 'lisa', 'is', '?', 'what', 'am', 'i', 'gon', 'na', 'do', '?', 'now', 'my', 'little', 'sister', 'goes', 'the', 'same', 'high', 'school', '.', 'the', 'party', 'over', '.', 'so', 'who', 'do', 'you', 'have', 'first', 'period', '?'], ['everyone', 'wants', 'to', 'know', 'where', 'lisa', 'is', '.', 'how', 'should', 'i', 'know', 'where', 'lisa', 'is', '?', 'what', 'am', 'i', 'gon', 'na', 'do', '?', 'now', 'my', 'little', 'sister', 'goes', 'to', 'the', 'same', 'high', 'school', '.', 'the', 'party', "'s", 'over', '.', 'so', 'who', 'do', 'you', 'have', 'first', 'period', '?'])
# (['sis', '.'], ['sis', '.'])
# (['you', "'re", 'fired', '.'], ['you', "'re", 'fired', '.'])
# (['did', 'you', 'threaten', 'this', 'customer', 'or', 'use', 'profanity', 'in', 'any', 'way', '?'], ['did', 'you', 'threaten', 'this', 'customer', 'or', 'use', 'profanity', 'in', 'any', 'way', '?'])
# (['he', 'insulted', 'me', 'first', '.', 'he', 'called', 'me', 'moron', '.'], ['he', 'insulted', 'me', 'first', '.', 'he', 'called', 'me', 'a', 'moron', '.'])
# (['did', 'you', 'threaten', 'this', 'man', 'or', 'use', 'profanity', 'in', 'any', 'way', '?'], ['did', 'you', 'threaten', 'this', 'man', 'or', 'use', 'profanity', 'in', 'any', 'way', '?'])
# (['come', 'on', '.', 'clean', 'that', 'counter', 'off', 'brad', '.', 'let', "'s", 'go', '.', 'play', 'ball', '.'], ['come', 'on', '.', 'clean', 'that', 'counter', 'off', 'brad', '.', 'let', "'s", 'go', '.', 'play', 'ball', '.'])
# (['but', 'they', 'were', "n't", 'mine', '.'], ['but', 'they', 'were', "n't", 'mine', '.'])
# (['they', 'were', 'left', 'over', 'from', 'the', 'last', 'shift', '.'], ['they', 'were', 'left', 'over', 'from', 'the', 'last', 'shift', '.'])
# (['any', 'problems', '?'], ['any', 'problems', '?'])
# (['jeff', 'you', 'have', 'company', '!'], ['jeff', 'you', 'have', 'company', '!'])
# (['dad', 'says', '!'], ['dad', 'says', '!'])
# (['leave', 'me', 'alone', '.'], ['leave', 'me', 'alone', '.'])
# (['leave', 'me', 'alone', '!'], ['leave', 'me', 'alone', '!'])
# (['ugh', '.'], ['ugh', '.'])
# (['dad', 'says', 'you', 'have', 'to', 'get', 'up', '!'], ['dad', 'says', 'you', 'have', 'to', 'get', 'up', '!'])
# (['get', 'going', '.'], ['get', 'going', '.'])
# (['all', 'right', '.', 'all', 'right', '.', 'i', 'just', 'cleaned', 'b-8', '.', 'give', 'me', 'break', '.'], ['all', 'right', '.', 'all', 'right', '.', 'i', 'just', 'cleaned', 'b-8', '.', 'give', 'me', 'a', 'break', '.'])
# (['mike', '!', 'you', 'have', 'a', 'mess', 'on', 'c-9', '!'], ['mike', '!', 'you', 'have', 'a', 'mess', 'on', 'c-9', '!'])
# (['half', '.', 'okay', '?', 'seventy-five', 'dollars', '.', 'and', 'a', 'ride', 'to', 'the', 'clinic', '.'], ['half', '.', 'okay', '?', 'seventy-five', 'dollars', '.', 'and', 'a', 'ride', 'to', 'the', 'clinic', '.'])
# (['does', "n't", 'sound', 'free', 'to', 'me', '.', 'so', 'you', 'want', 'me', 'to', 'pay', 'for', 'it', '?'], ['does', "n't", 'sound', 'free', 'to', 'me', '.', 'so', 'you', 'want', 'me', 'to', 'pay', 'for', 'it', '?'])
# (['yeah', '.', 'my', 'brother', 'art', 'got', 'his', 'girlfriend', 'one', 'once', '.'], ['yeah', '.', 'my', 'brother', 'art', 'got', 'his', 'girlfriend', 'one', 'once', '.'])
# (['we', "'ve", 'got', 'get', 'abortion', '?'], ['we', "'ve", 'got', 'to', 'get', 'an', 'abortion', '?'])
# (['there', "'s", 'only', 'one', 'thing', 'we', 'can', 'do', '.', 'we', 'got', 'to', 'get', 'rid', 'of', 'it', '.', 'we', 'got', 'to', 'get', 'an', 'abortion', '.'], ['there', "'s", 'only', 'one', 'thing', 'we', 'can', 'do', '.', 'we', "'ve", 'got', 'to', 'get', 'rid', 'of', 'it', '.', 'we', "'ve", 'got', 'to', 'get', 'an', 'abortion', '.'])
# (['take', 'that', 'back', '.'], ['take', 'that', 'back', '.'])
# (['i', 'know', 'it', "'s", 'yours', '.'], ['i', 'know', 'it', "'s", 'yours', '.'])
# (['how', 'do', 'you', 'know', 'it', 'mine', '?', 'we', 'only', 'did', 'it', 'once', '.'], ['how', 'do', 'you', 'know', 'it', "'s", 'mine', '?', 'we', 'only', 'did', 'it', 'once', '.'])
# (['mike', '.', 'i', 'want', 'you', 'to', 'know', 'that', 'i', "'m", 'pregnant', '.'], ['mike', '.', 'i', 'want', 'you', 'to', 'know', 'that', 'i', "'m", 'pregnant', '.'])
# (['why', 'do', "n't", 'you', 'call', 'me', 'up', 'tonight', '?'], ['why', 'do', "n't", 'you', 'call', 'me', 'up', 'tonight', '?'])
# (['what', '?', 'now', '?'], ['what', '?', 'now', '?'])
# (['what', 'going', 'on', '?'], ['what', "'s", 'going', 'on', '?'])
# (['hello', '.'], ['hello', '.'])
# (['i', "'m", 'in', 'a', 'hurry', 'too', '.', 'i', 'just', 'thought', 'i', 'could', 'say', 'hi', 'you', '.'], ['i', "'m", 'in', 'a', 'hurry', 'too', '.', 'i', 'just', 'thought', 'i', 'could', 'say', 'hi', 'to', 'you', '.'])
# (['i', 'did', "n't", 'see', 'you', 'this', 'morning', '.'], ['i', 'did', "n't", 'see', 'you', 'this', 'morning', '.'])
# (['oh', '.', 'hi', '.'], ['oh', '.', 'hi', '.'])
# (['i', 'guess', 'i', 'did', '.'], ['i', 'guess', 'i', 'did', '.'])
# (['i', 'think', 'i', 'came', '.', 'did', "n't", 'you', 'feel', 'it', '?'], ['i', 'think', 'i', 'came', '.', 'did', "n't", 'you', 'feel', 'it', '?'])
# (['what', 'wrong', '?'], ['what', "'s", 'wrong', '?'])
# (['i', "'m", 'sorry', '.', 'i', "'m", 'really', 'sorry', '.'], ['i', "'m", 'sorry', '.', 'i', "'m", 'really', 'sorry', '.'])
# (['i', 'think', 'we', "'re", 'making', 'lot', 'of', 'noise', '.'], ['i', 'think', 'we', "'re", 'making', 'a', 'lot', 'of', 'noise', '.'])
# (['what', '?', 'are', 'you', 'all', 'right', '?'], ['what', '?', 'are', 'you', 'all', 'right', '?'])
# (['let', 'continue', '.'], ['let', "'s", 'continue', '.'])
# (['i', 'want', 'you', 'know', 'that', 'it', 'your', 'final', 'decision', 'if', 'we', 'should', 'continue', 'or', 'not', '.'], ['i', 'want', 'you', 'to', 'know', 'that', 'it', "'s", 'your', 'final', 'decision', 'if', 'we', 'should', 'continue', 'or', 'not', '.'])
# (['how', 'about', 'both', 'of', 'us', 'at', 'same', 'time', '?'], ['how', 'about', 'both', 'of', 'us', 'at', 'the', 'same', 'time', '?'])
# (['you', 'first', '.'], ['you', 'first', '.'])
# (['no', '.', 'are', 'you', 'crazy', '?'], ['no', '.', 'are', 'you', 'crazy', '?'])
# (['so', 'are', 'you', '.', 'are', 'you', 'shaking', '?'], ['so', 'are', 'you', '.', 'are', 'you', 'shaking', '?'])
# (['you', "'re", 'a', 'really', 'good', 'kisser', '.'], ['you', "'re", 'a', 'really', 'good', 'kisser', '.'])
# (['come', 'on', '...'], ['come', 'on', '...'])
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-81-656f2d69253f> in <module>
# ----> 1 for i in pairs:
#       2     print(i)
#
# <ipython-input-65-42a8a4da27f5> in read_samples_by_string(self, path)
#      30
#      31     def read_samples_by_string(self, path):
# ---> 32         for tokens in self.read_tokens(path):
#      33             source = []
#      34             target = []
#
# <ipython-input-65-42a8a4da27f5> in read_tokens(self, path)
#      55     def read_tokens(self, path):
#      56         for line in range(len(path)):
# ---> 57             linep = path.iloc[line,:][0]
#      58             yield linep.lower().strip().split()
#
# ~/Music/Grammar-Correction/venv/lib/python3.5/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1488                         for x in key)
#    1489             try:
# -> 1490                 if self._is_scalar_access(key):
#    1491                     return self._getitem_scalar(key)
#    1492             except (KeyError, IndexError, AttributeError):
#
# ~/Music/Grammar-Correction/venv/lib/python3.5/site-packages/pandas/core/indexing.py in _is_scalar_access(self, key)
#    2092         # a) avoid getting things via sections and (to minimize dtype changes)
#    2093         # b) provide a performant path
# -> 2094         if not hasattr(key, '__len__'):
#    2095             return False
#    2096
#
# KeyboardInterrupt:

# %%
for i in range(1,len(data)):
    print(data[i,:])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-ce29112b1c4d> in <module>
#       1 for i in range(1,len(data)):
# ----> 2     print(data[i,:])
#
# ~/Music/Grammar-Correction/venv/lib/python3.5/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# ~/Music/Grammar-Correction/venv/lib/python3.5/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2655                                  'backfill or nearest lookups')
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#    2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(1, slice(None, None, None))' is an invalid key

# %%
data[1][0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/Music/Grammar-Correction/venv/lib/python3.5/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-38-c01f3793da60> in <module>
# ----> 1 data[1][0]
#
# ~/Music/Grammar-Correction/venv/lib/python3.5/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# ~/Music/Grammar-Correction/venv/lib/python3.5/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1

# %%
len(data)
# Out:
# 197615

# %%
import csv
from tqdm import tqdm 
import pandas as pd

# %%
with open('data.csv','w') as f:
    csvwriter = csv.writer(f)  
    csvwriter.writerow(['source','target'])  
    for row in tqdm(pairs, total=197615):
        
        src = " ".join(row[0])
        trg = " ".join(row[1])
#         print(src)
#         print(trg)
        csvwriter.writerow([src,trg])
# Out:
# 100%|██████████| 197615/197615 [00:34<00:00, 5763.00it/s]

# %%
dataNew = pd.read_csv("data.csv", error_bad_lines=False)

# %%
len(dataNew)
# Out:
# 197615

# %%
dataNew
# Out:
#                                                    source  \
# 0                                            they do to !
# 1                                             i hope so .
# 2                                              she okay ?
# 3                                             let 's go .
# 4                                                     wow
# 5       okay -- you 're gon na need to learn how to lie .
# 6                                                      no
# 7       i 'm kidding . you know how sometimes you just...
# 8                       like my fear of wearing pastels ?
# 9                                    the `` real you '' .
# 10                                      what good stuff ?
# 11      i figured you 'd get to the good stuff eventua...
# 12      thank god ! if i had hear one more story about...
# 13                                            what crap ?
# 14                              do you listen this crap ?
# 15                                                 no ...
# 16                         you always been this selfish ?
# 17                                                    but
# 18                      then that 's all you had to say .
# 19                                                i was ?
# 20                                                   tons
# 21                                     have fun tonight ?
# 22                   i believe we share an art instructor
# 23                                    you know chastity ?
# 24                                                   hi .
# 25      who knows ? all i 've ever heard her say is th...
# 26       so that 's kind of guy she likes ? pretty ones ?
# 27                                       she 's not a ...
# 28      i workin ' on it . but she does n't seem to be...
# 29                                            sure have .
# ...                                                   ...
# 197585  were they in good heart as they entered enemy ...
# 197586                     1 saw you lead our cavalry sir
# 197587  and the threat of counter invasion no longer e...
# 197588                          i explaining my reasons .
# 197589  intelligence ? sources of your own ? did it no...
# 197590  you intended to bring your reserves across riv...
# 197591  my lord . this list was prepared for you . i d...
# 197592  i thought it might be more effective to find s...
# 197593      they come well recommended do they ? durnford
# 197594               splendid horsemanship who are they ?
# 197595                                              yes ?
# 197596                                        thank you .
# 197597  what that strange name newspaper chap 's called ?
# 197598              but will they make good use of them ?
# 197599  yes . i see you issued each of them with a mar...
# 197600  how quickly can you move your artillery forward ?
# 197601                                              yes .
# 197602                                           stuart ?
# 197603  choose your targets men . that 's right watch ...
# 197604  ft could be you flatter yourself coghill it 's...
# 197605      well that one . one who keeps looking at me .
# 197606                                        which one ?
# 197607  do you think she might be interested in someone ?
# 197608  well that 's typical of her majesty army . app...
# 197609  um . their are rumours that my lord chelmsford...
# 197610  lighting coghill ' 5 cigar : our good colonel ...
# 197611  i think chelmsford wants good man on border wh...
# 197612  lord chelmsford seems to want me to stay back ...
# 197613  i 'm to take the sikali with main column the r...
# 197614  colonel durnford ... william vereker . i hear ...
#
#                                                    target
# 0                                            they do to !
# 1                                             i hope so .
# 2                                              she okay ?
# 3                                             let 's go .
# 4                                                     wow
# 5       okay -- you 're gon na need to learn how to lie .
# 6                                                      no
# 7       i 'm kidding . you know how sometimes you just...
# 8                       like my fear of wearing pastels ?
# 9                                    the `` real you '' .
# 10                                      what good stuff ?
# 11      i figured you 'd get to the good stuff eventua...
# 12      thank god ! if i had to hear one more story ab...
# 13                                            what crap ?
# 14                           do you listen to this crap ?
# 15                                                 no ...
# 16                         you always been this selfish ?
# 17                                                    but
# 18                      then that 's all you had to say .
# 19                                                i was ?
# 20                                                   tons
# 21                                     have fun tonight ?
# 22                   i believe we share an art instructor
# 23                                    you know chastity ?
# 24                                                   hi .
# 25      who knows ? all i 've ever heard her say is th...
# 26      so that 's the kind of guy she likes ? pretty ...
# 27                                       she 's not a ...
# 28      i 'm workin ' on it . but she does n't seem to...
# 29                                            sure have .
# ...                                                   ...
# 197585  were they in good heart as they entered enemy ...
# 197586                     1 saw you lead our cavalry sir
# 197587  and the threat of counter invasion no longer e...
# 197588                       i 'm explaining my reasons .
# 197589  intelligence ? sources of your own ? did it no...
# 197590  you intended to bring your reserves across the...
# 197591  my lord . this list was prepared for you . i d...
# 197592  i thought it might be more effective to find s...
# 197593      they come well recommended do they ? durnford
# 197594               splendid horsemanship who are they ?
# 197595                                              yes ?
# 197596                                        thank you .
# 197597  what 's that strange name the newspaper chap '...
# 197598              but will they make good use of them ?
# 197599  yes . i see you 've issued each of them with a...
# 197600  how quickly can you move your artillery forward ?
# 197601                                              yes .
# 197602                                           stuart ?
# 197603  choose your targets men . that 's right watch ...
# 197604  ft could be you flatter yourself coghill it 's...
# 197605  well that one . the one who keeps looking at me .
# 197606                                        which one ?
# 197607  do you think she might be interested in someone ?
# 197608  well that 's typical of her majesty 's army . ...
# 197609  um . there are rumours that my lord chelmsford...
# 197610  lighting coghill ' 5 cigar : our good colonel ...
# 197611  i think chelmsford wants a good man on the bor...
# 197612  lord chelmsford seems to want me to stay back ...
# 197613  i 'm to take the sikali with the main column t...
# 197614  colonel durnford ... william vereker . i hear ...
#
# [197615 rows x 2 columns]

# %%
from sklearn.model_selection import train_test_split

#Creating a train and validation sentence
train, val = train_test_split(dataNew, test_size=0.1)

# %%
train.to_csv("train.csv", index=False)
val.to_csv("val.csv",index=False)

# %%
import random
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import spacy
from utils import translate_sentence, bleu, save_checkpoint, load_checkpoint
from torch.utils.tensorboard import SummaryWriter  # to print to tensorboard
# from torchtext.datasets import Multi30k
from torchtext.data import Field, BucketIterator, TabularDataset
torch.backends.cudnn.benchmark = True
torch.backends.cudnn.enabled = True
import GPUtil

"""
To install spacy languages do:
python -m spacy download en
python -m spacy download de
"""
# spacy_ger = spacy.load("de")
spacy_eng = spacy.load("en")


# def tokenize_ger(text):
#     return [tok.text for tok in spacy_ger.tokenizer(text)]


def tokenize_eng(text):
    return [tok.text for tok in spacy_eng.tokenizer(text)]


# german = Field(tokenize=tokenize_ger, lower=True, init_token="<sos>", eos_token="<eos>")

english = Field(
    tokenize=tokenize_eng, lower=True, init_token="<sos>", eos_token="<eos>"
)

# train_data, valid_data, test_data = Multi30k.splits(
#     exts=(".de", ".en"), fields=(german, english)
# )

# %%
print("Start: tokenizing the train and validation set")
data_fields = [('source', english), ('target', english)]

train, val = TabularDataset.splits(path='./', train='train.csv', validation='val.csv', format='csv', fields=data_fields)
print("train ",len(train))
print("val ",len(val))
print("Done with creation of DataSet Object")
# Out:
# Start: tokenizing the train and validation set
# train  177854
# val  19763
# Done with creation of DataSet Object

# %%
english.build_vocab(train, max_size=10000, min_freq=2)

# %%
print(len(english.vocab))
# Out:
# 10004

# %%
    DROPOUT_TOKENS = ["a", "an", "the", "'ll", "'s", "'m", "'ve", "to"]  # Add "to"

    REPLACEMENTS = ["their", "there", "then", "than"]

# %%
CORRECTIVE_TOKENS = DROPOUT_TOKENS + REPLACEMENTS

# %% [markdown]
# # Creation of Model

# %% [markdown]
# ## Encoder

# %%
class Encoder(nn.Module):
    def __init__(self, input_size, embedding_size, hidden_size, num_layers, p):
        super(Encoder, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers

        self.embedding = nn.Embedding(input_size, embedding_size)
        self.rnn = nn.LSTM(embedding_size, hidden_size, num_layers, bidirectional=True)

        self.fc_hidden = nn.Linear(hidden_size * 2, hidden_size)
        self.fc_cell = nn.Linear(hidden_size * 2, hidden_size)
        self.dropout = nn.Dropout(p)

    def forward(self, x):
        # x: (seq_length, N) where N is batch size

        embedding = self.dropout(self.embedding(x))
        # embedding shape: (seq_length, N, embedding_size)

        encoder_states, (hidden, cell) = self.rnn(embedding)
        # outputs shape: (seq_length, N, hidden_size)

        # Use forward, backward cells and hidden through a linear layer
        # so that it can be input to the decoder which is not bidirectional
        # Also using index slicing ([idx:idx+1]) to keep the dimension
        hidden = self.fc_hidden(torch.cat((hidden[0:1], hidden[1:2]), dim=2))
        cell = self.fc_cell(torch.cat((cell[0:1], cell[1:2]), dim=2))
        del embedding
        torch.cuda.empty_cache()
        return encoder_states, hidden, cell

# %% [markdown]
# ## Decoder

# %%
class Decoder(nn.Module):
    def __init__(
        self, input_size, embedding_size, hidden_size, output_size, num_layers, p
    ):
        super(Decoder, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers

        self.embedding = nn.Embedding(input_size, embedding_size)
        self.rnn = nn.LSTM(hidden_size * 2 + embedding_size, hidden_size, num_layers)

        self.energy = nn.Linear(hidden_size * 3, 1)
        self.fc = nn.Linear(hidden_size, output_size)
        self.dropout = nn.Dropout(p)
        self.softmax = nn.Softmax(dim=0)
        self.relu = nn.ReLU()

    def forward(self, x, encoder_states, hidden, cell):
        x = x.unsqueeze(0)
        # x: (1, N) where N is the batch size

        embedding = self.dropout(self.embedding(x))
        # embedding shape: (1, N, embedding_size)

        sequence_length = encoder_states.shape[0]
        h_reshaped = hidden.repeat(sequence_length, 1, 1)
        # h_reshaped: (seq_length, N, hidden_size*2)

        energy = self.relu(self.energy(torch.cat((h_reshaped, encoder_states), dim=2)))
        # energy: (seq_length, N, 1)

        attention = self.softmax(energy)
        # attention: (seq_length, N, 1)

        # attention: (seq_length, N, 1), snk
        # encoder_states: (seq_length, N, hidden_size*2), snl
        # we want context_vector: (1, N, hidden_size*2), i.e knl
        context_vector = torch.einsum("snk,snl->knl", attention, encoder_states)

        rnn_input = torch.cat((context_vector, embedding), dim=2)
        # rnn_input: (1, N, hidden_size*2 + embedding_size)

        outputs, (hidden, cell) = self.rnn(rnn_input, (hidden, cell))
        # outputs shape: (1, N, hidden_size)

        predictions = self.fc(outputs).squeeze(0)
        # predictions: (N, hidden_size)
        
        del x, embedding,energy, attention,outputs
        torch.cuda.empty_cache()
        return predictions, hidden, cell

# %% [markdown]
# ## Seq2seq

# %%
class Seq2Seq(nn.Module):
    def __init__(self, encoder, decoder):
        super(Seq2Seq, self).__init__()
        self.encoder = encoder
        self.decoder = decoder

    def forward(self, source, target, teacher_force_ratio=0.5):
        batch_size = source.shape[1]
        target_len = target.shape[0]
        target_vocab_size = len(english.vocab)

        outputs = torch.zeros(target_len, batch_size, target_vocab_size).to(device)
        encoder_states, hidden, cell = self.encoder(source)

        # First input will be <SOS> token
        x = target[0]

        for t in range(1, target_len):
            # At every time step use encoder_states and update hidden, cell
            output, hidden, cell = self.decoder(x, encoder_states, hidden, cell)

            # Store prediction for current time step
            outputs[t] = output

            # Get the best word the Decoder predicted (index in the vocabulary)
            best_guess = output.argmax(1)

            # With probability of teacher_force_ratio we take the actual next word
            # otherwise we take the word that the Decoder predicted it to be.
            # Teacher Forcing is used so that the model gets used to seeing
            # similar inputs at training and testing time, if teacher forcing is 1
            # then inputs at test time might be completely different than what the
            # network is used to. This was a long comment.
            x = target[t] if random.random() < teacher_force_ratio else best_guess
        del x, encoder_states, hidden, cell,target_vocab_size
        torch.cuda.empty_cache()
        return outputs

# %% [markdown]
# ## Model Initialisation

# %%
torch.cuda.is_available()
# Out:
# True

# %%
### We're ready to define everything we need for training our Seq2Seq model ###
device = torch.device("cuda:1" if torch.cuda.is_available() else "cpu")
device2 = torch.device("cuda:2" if torch.cuda.is_available() else "cpu")
load_model = False
save_model = True

# Training hyperparameters
num_epochs = 100
learning_rate = 3e-4
batch_size = 32

# Model hyperparameters
input_size_encoder = len(english.vocab)
input_size_decoder = len(english.vocab)
output_size = len(english.vocab)
encoder_embedding_size = 300
decoder_embedding_size = 300
hidden_size = 1024
num_layers = 1
enc_dropout = 0.0
dec_dropout = 0.0

# Tensorboard to get nice loss plot
writer = SummaryWriter("runs/loss_plot")
step = 0
GPUtil.showUtilization()
# Out:
# | ID | GPU | MEM |
# ------------------
# |  0 |  7% |  4% |
# |  1 |  0% |  0% |
# |  2 |  0% |  0% |
# |  3 |  0% |  0% |

# %%
train_iterator = BucketIterator(
    train,
    batch_size=batch_size,
    sort_within_batch=True,
    sort_key=lambda x: len(x.source),
    device=device2
)
GPUtil.showUtilization()
# Out:
# | ID | GPU | MEM |
# ------------------
# |  0 |  5% |  4% |
# |  1 |  0% |  0% |
# |  2 |  0% |  0% |
# |  3 |  0% |  0% |

# %% [markdown]
# ## creation of model, encoder and decoder

# %%
val[1].target
# Out:
# ['wait', '.', 'i', 'think', 'we', 'understand', 'each', 'other', '.']

# %%
encoder_net = Encoder(
    input_size_encoder, encoder_embedding_size, hidden_size, num_layers, enc_dropout
).to(device)
GPUtil.showUtilization()
decoder_net = Decoder(
    input_size_decoder,
    decoder_embedding_size,
    hidden_size,
    output_size,
    num_layers,
    dec_dropout,
).to(device2)

model = Seq2Seq(encoder_net, decoder_net).to(device)
model = torch.nn.DataParallel(model, device_ids=[1,2]).to(device)
GPUtil.showUtilization()
# model = model.module()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)
model = model.module
pad_idx = english.vocab.stoi["<pad>"]
criterion = nn.CrossEntropyLoss(ignore_index=pad_idx)

if load_model:
    load_checkpoint(torch.load("my_checkpoint.pth.tar"), model, optimizer)

sentence = (
    "I don't want there food"
    "the Cardinals did better then the Cubs in the offseason"
)
GPUtil.showUtilization()
# Out:
# | ID | GPU | MEM |
# ------------------
# |  0 |  5% |  4% |
# |  1 |  8% |  9% |
# |  2 |  0% |  0% |
# |  3 |  0% |  0% |
# | ID | GPU | MEM |
# ------------------
# |  0 |  5% |  4% |
# |  1 |  1% | 11% |
# |  2 | 17% |  9% |
# |  3 |  0% |  0% |
# | ID | GPU | MEM |
# ------------------
# |  0 |  6% |  4% |
# |  1 |  0% | 11% |
# |  2 |  0% |  9% |
# |  3 |  0% |  0% |

# %%
for epoch in range(num_epochs):
    print("[Epoch {} / {}]".format(epoch,num_epochs))

    if save_model:
        checkpoint = {
            "state_dict": model.state_dict(),
            "optimizer": optimizer.state_dict(),
        }
        save_checkpoint(checkpoint)

    model.eval()

    translated_sentence = translate_sentence(
        model, sentence, english, english, device, max_length=50
    )

    print("Translated example sentence: \n {}".format(translated_sentence))

    model.train()
    GPUtil.showUtilization()

    for batch_idx, batch in enumerate(train_iterator):
        # Get input and targets and get to cuda
        inp_data = batch.source.to(device)
        target = batch.target.to(device)

        # Forward prop
        output = model(inp_data, target)
#         GPUtil.showUtilization()
        
        # Output is of shape (trg_len, batch_size, output_dim) but Cross Entropy Loss
        # doesn't take input in that form. For example if we have MNIST we want to have
        # output to be: (N, 10) and targets just (N). Here we can view it in a similar
        # way that we have output_words * batch_size that we want to send in into
        # our cost function, so we need to do some reshapin. While we're at it
        # Let's also remove the start token while we're at it
        output = output[1:].reshape(-1, output.shape[2])
        target = target[1:].reshape(-1)

        optimizer.zero_grad()
#         GPUtil.showUtilization()
        loss = criterion(output, target)
        
        del output, inp_data, target
        torch.cuda.empty_cache()
        for i in range(10000000):
            continue
        # Back prop
        loss.mean().backward()

        # Clip to avoid exploding gradient issues, makes sure grads are
        # within a healthy range
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1)

        # Gradient descent step
        optimizer.step()

        # Plot to tensorboard
        writer.add_scalar("Training loss", loss, global_step=step)
        step += 1
        del loss
        torch.cuda.empty_cache()
        for i in range(10000000):
            continue
# running on entire test data takes a while
score = bleu(val[1:100], model, english, english, device)
print("Bleu score {}".format(score * 100))
# Out:
# [Epoch 0 / 100]
# => Saving checkpoint
# Translated example sentence:
#  ['local', 'fame', 'solve', 'undoubtedly', 'accomplice', 'ears', 'destroys', 'herbert', 'functional', 'scientific', 'scanner', 'selected', 'ties', 'laugh', 'foods', 'faced', 'increase', 'interest', 'script', 'spice', 'crashing', 'sue', 'horn', 'pig', 'found', 'eastern', 'halo', 'cramp', 'cramp', 'cramp', 'cramp', 'cramp', 'slippers', 'touched', 'de', 'parade', 'habits', 'sheets', 'offer', 'joints', 'samuel', 'band', 'dislike', 'copy', 'seem', 'herbert', 'agnes', 'chalk', 'cape', 'iii']
# | ID | GPU | MEM |
# ------------------
# |  0 |  2% | 11% |
# |  1 | 45% | 10% |
# |  2 |  0% |  7% |
# |  3 |  0% |  0% |
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-15-2d08143ee508> in <module>
#      26
#      27         # Forward prop
# ---> 28         output = model(inp_data, target)
#      29 #         GPUtil.showUtilization()
#      30
#
# ~/Music/Grammar-Correction/venv/lib/python3.5/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     545             result = self._slow_forward(*input, **kwargs)
#     546         else:
# --> 547             result = self.forward(*input, **kwargs)
#     548         for hook in self._forward_hooks.values():
#     549             hook_result = hook(self, input, result)
#
# <ipython-input-9-253595fb48a0> in forward(self, source, target, teacher_force_ratio)
#      18         for t in range(1, target_len):
#      19             # At every time step use encoder_states and update hidden, cell
# ---> 20             output, hidden, cell = self.decoder(x, encoder_states, hidden, cell)
#      21
#      22             # Store prediction for current time step
#
# ~/Music/Grammar-Correction/venv/lib/python3.5/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     545             result = self._slow_forward(*input, **kwargs)
#     546         else:
# --> 547             result = self.forward(*input, **kwargs)
#     548         for hook in self._forward_hooks.values():
#     549             hook_result = hook(self, input, result)
#
# <ipython-input-8-718a51b374cb> in forward(self, x, encoder_states, hidden, cell)
#      41         # rnn_input: (1, N, hidden_size*2 + embedding_size)
#      42
# ---> 43         outputs, (hidden, cell) = self.rnn(rnn_input, (hidden, cell))
#      44         # outputs shape: (1, N, hidden_size)
#      45
#
# ~/Music/Grammar-Correction/venv/lib/python3.5/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     545             result = self._slow_forward(*input, **kwargs)
#     546         else:
# --> 547             result = self.forward(*input, **kwargs)
#     548         for hook in self._forward_hooks.values():
#     549             hook_result = hook(self, input, result)
#
# ~/Music/Grammar-Correction/venv/lib/python3.5/site-packages/torch/nn/modules/rnn.py in forward(self, input, hx)
#     562             return self.forward_packed(input, hx)
#     563         else:
# --> 564             return self.forward_tensor(input, hx)
#     565
#     566 class GRU(RNNBase):
#
# ~/Music/Grammar-Correction/venv/lib/python3.5/site-packages/torch/nn/modules/rnn.py in forward_tensor(self, input, hx)
#     541         unsorted_indices = None
#     542
# --> 543         output, hidden = self.forward_impl(input, hx, batch_sizes, max_batch_size, sorted_indices)
#     544
#     545         return output, self.permute_hidden(hidden, unsorted_indices)
#
# ~/Music/Grammar-Correction/venv/lib/python3.5/site-packages/torch/nn/modules/rnn.py in forward_impl(self, input, hx, batch_sizes, max_batch_size, sorted_indices)
#     524         if batch_sizes is None:
#     525             result = _VF.lstm(input, hx, self._get_flat_weights(), self.bias, self.num_layers,
# --> 526                               self.dropout, self.training, self.bidirectional, self.batch_first)
#     527         else:
#     528             result = _VF.lstm(input, batch_sizes, hx, self._get_flat_weights(), self.bias,
#
# RuntimeError: CUDA out of memory. Tried to allocate 56.00 MiB (GPU 1; 7.93 GiB total capacity; 7.16 GiB already allocated; 38.56 MiB free; 146.20 MiB cached)
